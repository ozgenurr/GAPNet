# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import keras
import numpy as np # linear algebra
import keras.backend as K
import time as ti
import cv2
import os
import glob # for including images
import scipy.io as sio
from sklearn.metrics import classification_report, confusion_matrix
from keras import layers
from keras import models
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.python.keras.layers import *

from tensorflow.python.keras.optimizers import *
from keras.callbacks import *
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.activations import *
import keras.backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 4062 images belonging to 4 classes.
# (4062, 224, 224, 3)
# (4062, 4)

# %%
#Converting  our color images to a vector
x=x.reshape(4062,224*224*3)

# %%
x.shape
# Out:
# (4062, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (5532, 150528)

# %%
X_smote=X_smote.reshape(5532,224,224,3)

# %% [markdown]
# # 1. sınıf: 1179  2. sınıf: 1076 3. sınıf: 1142 4. sınıf: 1180

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (4062, 150528)
# Shape of X after SMOTE: (5532, 224, 224, 3)

# %%
"""
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
data_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
"""
# Out:
# "\ndisease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']\ndata_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'\ntrain_dir = os.path.join(data_dir)\n\ntrain_data = []\nfor defects_id, sp in enumerate(disease_types):\n    for file in os.listdir(os.path.join(train_dir, sp)):\n        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])\n\ntrain = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])\n\nSEED = 42\ntrain = train.sample(frac=1, random_state=SEED)\ntrain.index = np.arange(len(train)) # Reset indices\n"

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (5532, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
pip install keras_applications
# Out:
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications) (3.9.0)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)

# %%
pip install Keras
# Out:
# Requirement already satisfied: Keras in /usr/local/lib/python3.10/dist-packages (2.14.0)

# %%
from keras.utils import plot_model
from keras_applications.imagenet_utils import _obtain_input_shape
#from tensorflow.keras.engine.topology import get_source_inputs
from keras.layers import Input, Conv2D, MaxPool2D, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.layers import Activation, Dense
from keras.models import Model
import keras.backend as K



import os
from keras import backend as K
from keras.models import Model
#from keras.engine.topology import get_source_inputs
from keras.layers import Activation, Add, Concatenate, Conv2D, GlobalMaxPooling2D
from keras.layers import GlobalAveragePooling2D,Input, Dense
from keras.layers import MaxPool2D,AveragePooling2D, BatchNormalization, Lambda, DepthwiseConv2D
import numpy as np


def channel_split(x, name=''):
    # equipartition
    in_channles = x.shape.as_list()[-1]
    ip = in_channles // 2
    c_hat = Lambda(lambda z: z[:, :, :, 0:ip], name='%s/sp%d_slice' % (name, 0))(x)
    c = Lambda(lambda z: z[:, :, :, ip:], name='%s/sp%d_slice' % (name, 1))(x)
    return c_hat, c

def channel_shuffle(x):
    height, width, channels = x.shape.as_list()[1:]
    channels_per_split = channels // 2
    x = K.reshape(x, [-1, height, width, 2, channels_per_split])
    x = K.permute_dimensions(x, (0,1,2,4,3))
    x = K.reshape(x, [-1, height, width, channels])
    return x


def shuffle_unit(inputs, out_channels, bottleneck_ratio,strides=2,stage=1,block=1):
    if K.image_data_format() == 'channels_last':
        bn_axis = -1
    else:
        raise ValueError('Only channels last supported')

    prefix = 'stage{}/block{}'.format(stage, block)
    bottleneck_channels = int(out_channels * bottleneck_ratio)
    if strides < 2:
        c_hat, c = channel_split(inputs, '{}/spl'.format(prefix))
        inputs = c

    x = Conv2D(bottleneck_channels, kernel_size=(1,1), strides=1, padding='same', name='{}/1x1conv_1'.format(prefix))(inputs)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_1'.format(prefix))(x)
    x = Activation('relu', name='{}/relu_1x1conv_1'.format(prefix))(x)
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same', name='{}/3x3dwconv'.format(prefix))(x)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_3x3dwconv'.format(prefix))(x)
    x = Conv2D(bottleneck_channels, kernel_size=1,strides=1,padding='same', name='{}/1x1conv_2'.format(prefix))(x)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_2'.format(prefix))(x)
    x = Activation('relu', name='{}/relu_1x1conv_2'.format(prefix))(x)

    if strides < 2:
        ret = Concatenate(axis=bn_axis, name='{}/concat_1'.format(prefix))([x, c_hat])
    else:
        s2 = DepthwiseConv2D(kernel_size=3, strides=2, padding='same', name='{}/3x3dwconv_2'.format(prefix))(inputs)
        s2 = BatchNormalization(axis=bn_axis, name='{}/bn_3x3dwconv_2'.format(prefix))(s2)
        s2 = Conv2D(bottleneck_channels, kernel_size=1,strides=1,padding='same', name='{}/1x1_conv_3'.format(prefix))(s2)
        s2 = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_3'.format(prefix))(s2)
        s2 = Activation('relu', name='{}/relu_1x1conv_3'.format(prefix))(s2)
        ret = Concatenate(axis=bn_axis, name='{}/concat_2'.format(prefix))([x, s2])

    ret = Lambda(channel_shuffle, name='{}/channel_shuffle'.format(prefix))(ret)

    return ret


def block(x, channel_map, bottleneck_ratio, repeat=1, stage=1):
    x = shuffle_unit(x, out_channels=channel_map[stage-1],
                      strides=2,bottleneck_ratio=bottleneck_ratio,stage=stage,block=1)

    for i in range(1, repeat+1):
        x = shuffle_unit(x, out_channels=channel_map[stage-1],strides=1,
                          bottleneck_ratio=bottleneck_ratio,stage=stage, block=(1+i))

    return x


def ShuffleNetV2(include_top=True,
                 input_tensor=None,
                 scale_factor=1.0,
                 pooling='max',
                 input_shape=(32,32,3),
                 load_model=None,
                 num_shuffle_units=[3,7,3],
                 bottleneck_ratio=1,
                 classes=131):
    if K.backend() != 'tensorflow':
        raise RuntimeError('Only tensorflow supported for now')
    name = 'ShuffleNetV2_{}_{}_{}'.format(scale_factor, bottleneck_ratio, "".join([str(x) for x in num_shuffle_units]))
    input_shape = _obtain_input_shape(input_shape, default_size=224, min_size=28, require_flatten=include_top,
                                      data_format=K.image_data_format())
    out_dim_stage_two = {0.5:48, 1:116, 1.5:176, 2:244}

    if pooling not in ['max', 'avg']:
        raise ValueError('Invalid value for pooling')
    if not (float(scale_factor)*4).is_integer():
        raise ValueError('Invalid value for scale_factor, should be x over 4')
    exp = np.insert(np.arange(len(num_shuffle_units), dtype=np.float32), 0, 0)  # [0., 0., 1., 2.]
    out_channels_in_stage = 2**exp
    out_channels_in_stage *= out_dim_stage_two[bottleneck_ratio]  #  calculate output channels for each stage
    out_channels_in_stage[0] = 24  # first stage has always 24 output channels
    out_channels_in_stage *= scale_factor
    out_channels_in_stage = out_channels_in_stage.astype(int)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    # create shufflenet architecture
    x = Conv2D(filters=out_channels_in_stage[0], kernel_size=(3, 3), padding='same', use_bias=False, strides=(2, 2),
               activation='relu', name='conv1')(img_input)
    x = MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same', name='maxpool1')(x)

    # create stages containing shufflenet units beginning at stage 2
    for stage in range(len(num_shuffle_units)):
        repeat = num_shuffle_units[stage]
        x = block(x, out_channels_in_stage,
                   repeat=repeat,
                   bottleneck_ratio=bottleneck_ratio,
                   stage=stage + 2)

    if bottleneck_ratio < 2:
        k = 1024
    else:
        k = 2048
    x = Conv2D(k, kernel_size=1, padding='same', strides=1, name='1x1conv5_out', activation='relu')(x)

    if pooling == 'avg':
        x = GlobalAveragePooling2D(name='global_avg_pool')(x)
    elif pooling == 'max':
        x = GlobalMaxPooling2D(name='global_max_pool')(x)

    if include_top:
        x = Dense(classes, name='fc')(x)
        x = Activation('softmax', name='softmax')(x)

    if input_tensor:
        inputs = get_source_inputs(input_tensor)

    else:
        inputs = img_input

    model = Model(inputs, x, name=name)

    if load_model:
        model.load_weights('', by_name=True)

    return model

# %%
model = ShuffleNetV2( include_top=True, input_shape=(224, 224, 3), classes=4)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "ShuffleNetV2_1.0_1_373"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1 (Conv2D)              (None, 112, 112, 24)         648       ['input_1[0][0]']
#
#  maxpool1 (MaxPooling2D)     (None, 56, 56, 24)           0         ['conv1[0][0]']
#
#  stage2/block1/1x1conv_1 (C  (None, 56, 56, 116)          2900      ['maxpool1[0][0]']
#  onv2D)
#
#  stage2/block1/bn_1x1conv_1  (None, 56, 56, 116)          464       ['stage2/block1/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block1/relu_1x1conv  (None, 56, 56, 116)          0         ['stage2/block1/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block1/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block1/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block1/3x3dwconv_2   (None, 28, 28, 24)           240       ['maxpool1[0][0]']
#  (DepthwiseConv2D)
#
#  stage2/block1/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block1/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block1/bn_3x3dwconv  (None, 28, 28, 24)           96        ['stage2/block1/3x3dwconv_2[0]
#  _2 (BatchNormalization)                                            [0]']
#
#  stage2/block1/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block1/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block1/1x1_conv_3 (  (None, 28, 28, 116)          2900      ['stage2/block1/bn_3x3dwconv_2
#  Conv2D)                                                            [0][0]']
#
#  stage2/block1/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block1/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block1/bn_1x1conv_3  (None, 28, 28, 116)          464       ['stage2/block1/1x1_conv_3[0][
#   (BatchNormalization)                                              0]']
#
#  stage2/block1/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block1/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block1/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block1/bn_1x1conv_3[0
#  _3 (Activation)                                                    ][0]']
#
#  stage2/block1/concat_2 (Co  (None, 28, 28, 232)          0         ['stage2/block1/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block1/relu_1x1conv_3
#                                                                     [0][0]']
#
#  stage2/block1/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block1/concat_2[0][0]
#  fle (Lambda)                                                       ']
#
#  stage2/block2/spl/sp1_slic  (None, 28, 28, 116)          0         ['stage2/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block2/1x1conv_1 (C  (None, 28, 28, 116)          13572     ['stage2/block2/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage2/block2/bn_1x1conv_1  (None, 28, 28, 116)          464       ['stage2/block2/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block2/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block2/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block2/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block2/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block2/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block2/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block2/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block2/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block2/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block2/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block2/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block2/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block2/spl/sp0_slic  (None, 28, 28, 116)          0         ['stage2/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block2/concat_1 (Co  (None, 28, 28, 232)          0         ['stage2/block2/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block2/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage2/block2/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block2/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage2/block3/spl/sp1_slic  (None, 28, 28, 116)          0         ['stage2/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block3/1x1conv_1 (C  (None, 28, 28, 116)          13572     ['stage2/block3/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage2/block3/bn_1x1conv_1  (None, 28, 28, 116)          464       ['stage2/block3/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block3/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block3/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block3/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block3/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block3/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block3/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block3/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block3/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block3/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block3/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block3/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block3/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block3/spl/sp0_slic  (None, 28, 28, 116)          0         ['stage2/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block3/concat_1 (Co  (None, 28, 28, 232)          0         ['stage2/block3/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block3/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage2/block3/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block3/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage2/block4/spl/sp1_slic  (None, 28, 28, 116)          0         ['stage2/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block4/1x1conv_1 (C  (None, 28, 28, 116)          13572     ['stage2/block4/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage2/block4/bn_1x1conv_1  (None, 28, 28, 116)          464       ['stage2/block4/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block4/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block4/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage2/block4/3x3dwconv (D  (None, 28, 28, 116)          1160      ['stage2/block4/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage2/block4/bn_3x3dwconv  (None, 28, 28, 116)          464       ['stage2/block4/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block4/1x1conv_2 (C  (None, 28, 28, 116)          13572     ['stage2/block4/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage2/block4/bn_1x1conv_2  (None, 28, 28, 116)          464       ['stage2/block4/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage2/block4/relu_1x1conv  (None, 28, 28, 116)          0         ['stage2/block4/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage2/block4/spl/sp0_slic  (None, 28, 28, 116)          0         ['stage2/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage2/block4/concat_1 (Co  (None, 28, 28, 232)          0         ['stage2/block4/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage2/block4/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage2/block4/channel_shuf  (None, 28, 28, 232)          0         ['stage2/block4/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block1/1x1conv_1 (C  (None, 28, 28, 232)          54056     ['stage2/block4/channel_shuffl
#  onv2D)                                                             e[0][0]']
#
#  stage3/block1/bn_1x1conv_1  (None, 28, 28, 232)          928       ['stage3/block1/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block1/relu_1x1conv  (None, 28, 28, 232)          0         ['stage3/block1/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block1/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block1/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block1/3x3dwconv_2   (None, 14, 14, 232)          2320      ['stage2/block4/channel_shuffl
#  (DepthwiseConv2D)                                                  e[0][0]']
#
#  stage3/block1/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block1/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block1/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block1/3x3dwconv_2[0]
#  _2 (BatchNormalization)                                            [0]']
#
#  stage3/block1/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block1/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block1/1x1_conv_3 (  (None, 14, 14, 232)          54056     ['stage3/block1/bn_3x3dwconv_2
#  Conv2D)                                                            [0][0]']
#
#  stage3/block1/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block1/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block1/bn_1x1conv_3  (None, 14, 14, 232)          928       ['stage3/block1/1x1_conv_3[0][
#   (BatchNormalization)                                              0]']
#
#  stage3/block1/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block1/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block1/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block1/bn_1x1conv_3[0
#  _3 (Activation)                                                    ][0]']
#
#  stage3/block1/concat_2 (Co  (None, 14, 14, 464)          0         ['stage3/block1/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block1/relu_1x1conv_3
#                                                                     [0][0]']
#
#  stage3/block1/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block1/concat_2[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block2/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block2/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block2/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block2/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block2/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block2/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block2/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block2/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block2/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block2/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block2/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block2/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block2/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block2/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block2/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block2/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block2/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block2/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block2/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block2/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block2/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block2/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block2/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block3/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block3/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block3/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block3/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block3/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block3/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block3/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block3/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block3/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block3/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block3/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block3/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block3/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block3/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block3/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block3/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block3/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block3/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block3/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block3/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block3/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block3/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block3/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block4/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block4/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block4/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block4/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block4/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block4/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block4/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block4/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block4/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block4/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block4/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block4/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block4/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block4/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block4/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block4/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block4/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block4/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block4/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block4/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block4/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block4/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block4/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block5/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block4/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block5/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block5/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block5/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block5/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block5/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block5/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block5/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block5/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block5/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block5/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block5/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block5/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block5/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block5/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block5/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block5/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block5/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block4/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block5/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block5/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block5/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block5/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block5/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block6/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block5/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block6/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block6/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block6/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block6/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block6/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block6/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block6/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block6/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block6/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block6/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block6/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block6/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block6/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block6/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block6/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block6/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block6/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block5/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block6/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block6/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block6/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block6/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block6/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block7/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block6/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block7/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block7/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block7/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block7/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block7/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block7/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block7/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block7/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block7/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block7/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block7/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block7/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block7/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block7/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block7/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block7/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block7/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block6/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block7/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block7/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block7/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block7/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block7/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage3/block8/spl/sp1_slic  (None, 14, 14, 232)          0         ['stage3/block7/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block8/1x1conv_1 (C  (None, 14, 14, 232)          54056     ['stage3/block8/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage3/block8/bn_1x1conv_1  (None, 14, 14, 232)          928       ['stage3/block8/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block8/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block8/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage3/block8/3x3dwconv (D  (None, 14, 14, 232)          2320      ['stage3/block8/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage3/block8/bn_3x3dwconv  (None, 14, 14, 232)          928       ['stage3/block8/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block8/1x1conv_2 (C  (None, 14, 14, 232)          54056     ['stage3/block8/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage3/block8/bn_1x1conv_2  (None, 14, 14, 232)          928       ['stage3/block8/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage3/block8/relu_1x1conv  (None, 14, 14, 232)          0         ['stage3/block8/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage3/block8/spl/sp0_slic  (None, 14, 14, 232)          0         ['stage3/block7/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage3/block8/concat_1 (Co  (None, 14, 14, 464)          0         ['stage3/block8/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage3/block8/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage3/block8/channel_shuf  (None, 14, 14, 464)          0         ['stage3/block8/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block1/1x1conv_1 (C  (None, 14, 14, 464)          215760    ['stage3/block8/channel_shuffl
# ...
#  (DepthwiseConv2D)                                                  e[0][0]']
#
#  stage4/block1/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block1/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block1/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block1/3x3dwconv_2[0]
#  _2 (BatchNormalization)                                            [0]']
#
#  stage4/block1/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block1/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block1/1x1_conv_3 (  (None, 7, 7, 464)            215760    ['stage4/block1/bn_3x3dwconv_2
#  Conv2D)                                                            [0][0]']
#
#  stage4/block1/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block1/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block1/bn_1x1conv_3  (None, 7, 7, 464)            1856      ['stage4/block1/1x1_conv_3[0][
#   (BatchNormalization)                                              0]']
#
#  stage4/block1/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block1/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block1/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block1/bn_1x1conv_3[0
#  _3 (Activation)                                                    ][0]']
#
#  stage4/block1/concat_2 (Co  (None, 7, 7, 928)            0         ['stage4/block1/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block1/relu_1x1conv_3
#                                                                     [0][0]']
#
#  stage4/block1/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block1/concat_2[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block2/spl/sp1_slic  (None, 7, 7, 464)            0         ['stage4/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block2/1x1conv_1 (C  (None, 7, 7, 464)            215760    ['stage4/block2/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage4/block2/bn_1x1conv_1  (None, 7, 7, 464)            1856      ['stage4/block2/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block2/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block2/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage4/block2/3x3dwconv (D  (None, 7, 7, 464)            4640      ['stage4/block2/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage4/block2/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block2/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block2/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block2/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block2/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block2/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block2/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block2/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block2/spl/sp0_slic  (None, 7, 7, 464)            0         ['stage4/block1/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block2/concat_1 (Co  (None, 7, 7, 928)            0         ['stage4/block2/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block2/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage4/block2/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block2/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block3/spl/sp1_slic  (None, 7, 7, 464)            0         ['stage4/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block3/1x1conv_1 (C  (None, 7, 7, 464)            215760    ['stage4/block3/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage4/block3/bn_1x1conv_1  (None, 7, 7, 464)            1856      ['stage4/block3/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block3/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block3/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage4/block3/3x3dwconv (D  (None, 7, 7, 464)            4640      ['stage4/block3/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage4/block3/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block3/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block3/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block3/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block3/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block3/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block3/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block3/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block3/spl/sp0_slic  (None, 7, 7, 464)            0         ['stage4/block2/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block3/concat_1 (Co  (None, 7, 7, 928)            0         ['stage4/block3/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block3/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage4/block3/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block3/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  stage4/block4/spl/sp1_slic  (None, 7, 7, 464)            0         ['stage4/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block4/1x1conv_1 (C  (None, 7, 7, 464)            215760    ['stage4/block4/spl/sp1_slice[
#  onv2D)                                                             0][0]']
#
#  stage4/block4/bn_1x1conv_1  (None, 7, 7, 464)            1856      ['stage4/block4/1x1conv_1[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block4/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block4/bn_1x1conv_1[0
#  _1 (Activation)                                                    ][0]']
#
#  stage4/block4/3x3dwconv (D  (None, 7, 7, 464)            4640      ['stage4/block4/relu_1x1conv_1
#  epthwiseConv2D)                                                    [0][0]']
#
#  stage4/block4/bn_3x3dwconv  (None, 7, 7, 464)            1856      ['stage4/block4/3x3dwconv[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block4/1x1conv_2 (C  (None, 7, 7, 464)            215760    ['stage4/block4/bn_3x3dwconv[0
#  onv2D)                                                             ][0]']
#
#  stage4/block4/bn_1x1conv_2  (None, 7, 7, 464)            1856      ['stage4/block4/1x1conv_2[0][0
#   (BatchNormalization)                                              ]']
#
#  stage4/block4/relu_1x1conv  (None, 7, 7, 464)            0         ['stage4/block4/bn_1x1conv_2[0
#  _2 (Activation)                                                    ][0]']
#
#  stage4/block4/spl/sp0_slic  (None, 7, 7, 464)            0         ['stage4/block3/channel_shuffl
#  e (Lambda)                                                         e[0][0]']
#
#  stage4/block4/concat_1 (Co  (None, 7, 7, 928)            0         ['stage4/block4/relu_1x1conv_2
#  ncatenate)                                                         [0][0]',
#                                                                      'stage4/block4/spl/sp0_slice[
#                                                                     0][0]']
#
#  stage4/block4/channel_shuf  (None, 7, 7, 928)            0         ['stage4/block4/concat_1[0][0]
#  fle (Lambda)                                                       ']
#
#  1x1conv5_out (Conv2D)       (None, 7, 7, 1024)           951296    ['stage4/block4/channel_shuffl
#                                                                     e[0][0]']
#
#  global_max_pool (GlobalMax  (None, 1024)                 0         ['1x1conv5_out[0][0]']
#  Pooling2D)
#
#  fc (Dense)                  (None, 4)                    4100      ['global_max_pool[0][0]']
#
#  softmax (Activation)        (None, 4)                    0         ['fc[0][0]']
#
# ==================================================================================================
# Total params: 4022840 (15.35 MB)
# Trainable params: 3994720 (15.24 MB)
# Non-trainable params: 28120 (109.84 KB)
# __________________________________________________________________________________________________
# None

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist=model.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 70/70 [==============================] - ETA: 0s - loss: 1.4392 - accuracy: 0.6362
# Epoch 1: val_accuracy improved from -inf to 0.23126, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 70/70 [==============================] - 47s 115ms/step - loss: 1.4392 - accuracy: 0.6362 - val_loss: 1.3912 - val_accuracy: 0.2313
# Epoch 2/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.4015 - accuracy: 0.8573
# Epoch 2: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 5s 68ms/step - loss: 0.4030 - accuracy: 0.8572 - val_loss: 1.4099 - val_accuracy: 0.2313
# Epoch 3/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.3244 - accuracy: 0.8836
# Epoch 3: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 5s 68ms/step - loss: 0.3240 - accuracy: 0.8838 - val_loss: 1.4450 - val_accuracy: 0.2313
# Epoch 4/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.2410 - accuracy: 0.9171
# Epoch 4: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 5s 68ms/step - loss: 0.2419 - accuracy: 0.9171 - val_loss: 1.4635 - val_accuracy: 0.2313
# Epoch 5/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1560 - accuracy: 0.9402
# Epoch 5: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 5s 68ms/step - loss: 0.1559 - accuracy: 0.9403 - val_loss: 1.6293 - val_accuracy: 0.2313
# Epoch 6/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1185 - accuracy: 0.9558
# Epoch 6: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 5s 69ms/step - loss: 0.1184 - accuracy: 0.9559 - val_loss: 2.0526 - val_accuracy: 0.2313
# Epoch 7/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0712 - accuracy: 0.9731
# Epoch 7: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0711 - accuracy: 0.9731 - val_loss: 3.4091 - val_accuracy: 0.2313
# Epoch 8/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0552 - accuracy: 0.9812
# Epoch 8: val_accuracy improved from 0.23126 to 0.25203, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0552 - accuracy: 0.9812 - val_loss: 4.8913 - val_accuracy: 0.2520
# Epoch 9/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0857 - accuracy: 0.9699
# Epoch 9: val_accuracy improved from 0.25203 to 0.28997, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0855 - accuracy: 0.9699 - val_loss: 7.0057 - val_accuracy: 0.2900
# Epoch 10/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0890 - accuracy: 0.9708
# Epoch 10: val_accuracy improved from 0.28997 to 0.51039, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0888 - accuracy: 0.9708 - val_loss: 3.0396 - val_accuracy: 0.5104
# Epoch 11/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0502 - accuracy: 0.9819
# Epoch 11: val_accuracy improved from 0.51039 to 0.81391, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0501 - accuracy: 0.9819 - val_loss: 0.7202 - val_accuracy: 0.8139
# Epoch 12/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0422 - accuracy: 0.9873
# Epoch 12: val_accuracy improved from 0.81391 to 0.86992, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0422 - accuracy: 0.9873 - val_loss: 0.4459 - val_accuracy: 0.8699
# Epoch 13/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 0.9928
# Epoch 13: val_accuracy did not improve from 0.86992
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0238 - accuracy: 0.9925 - val_loss: 0.5967 - val_accuracy: 0.8672
# Epoch 14/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0946 - accuracy: 0.9694
# Epoch 14: val_accuracy did not improve from 0.86992
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0944 - accuracy: 0.9695 - val_loss: 4.1733 - val_accuracy: 0.6531
# Epoch 15/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0366 - accuracy: 0.9878
# Epoch 15: val_accuracy improved from 0.86992 to 0.91599, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0365 - accuracy: 0.9878 - val_loss: 1.2369 - val_accuracy: 0.9160
# Epoch 16/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0556 - accuracy: 0.9785
# Epoch 16: val_accuracy did not improve from 0.91599
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0565 - accuracy: 0.9781 - val_loss: 0.4959 - val_accuracy: 0.8925
# Epoch 17/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1629 - accuracy: 0.9497
# Epoch 17: val_accuracy did not improve from 0.91599
# 70/70 [==============================] - 5s 68ms/step - loss: 0.1630 - accuracy: 0.9496 - val_loss: 4.9644 - val_accuracy: 0.4851
# Epoch 18/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0522 - accuracy: 0.9814
# Epoch 18: val_accuracy did not improve from 0.91599
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0532 - accuracy: 0.9812 - val_loss: 1.0988 - val_accuracy: 0.7886
# Epoch 19/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0521 - accuracy: 0.9835
# Epoch 19: val_accuracy did not improve from 0.91599
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0531 - accuracy: 0.9833 - val_loss: 0.6252 - val_accuracy: 0.8356
# Epoch 20/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1525 - accuracy: 0.9524
# Epoch 20: val_accuracy improved from 0.91599 to 0.93044, saving model to best_model.h5
# 70/70 [==============================] - 5s 78ms/step - loss: 0.1522 - accuracy: 0.9525 - val_loss: 0.2641 - val_accuracy: 0.9304
# Epoch 21/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0238 - accuracy: 0.9932
# Epoch 21: val_accuracy improved from 0.93044 to 0.96025, saving model to best_model.h5
# 70/70 [==============================] - 5s 76ms/step - loss: 0.0237 - accuracy: 0.9932 - val_loss: 0.1385 - val_accuracy: 0.9603
# Epoch 22/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9986
# Epoch 22: val_accuracy improved from 0.96025 to 0.96929, saving model to best_model.h5
# 70/70 [==============================] - 5s 78ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.1245 - val_accuracy: 0.9693
# Epoch 23/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9989
# Epoch 23: val_accuracy did not improve from 0.96929
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.1256 - val_accuracy: 0.9639
# Epoch 24/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.96929
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9666
# Epoch 25/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 25: val_accuracy did not improve from 0.96929
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.1564 - val_accuracy: 0.9593
# Epoch 26/100
# 69/70 [============================>.] - ETA: 0s - loss: 4.1737e-04 - accuracy: 1.0000
# Epoch 26: val_accuracy improved from 0.96929 to 0.97200, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 4.1717e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9720
# Epoch 27/100
# 69/70 [============================>.] - ETA: 0s - loss: 1.7113e-04 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 67ms/step - loss: 1.7080e-04 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9693
# Epoch 28/100
# 69/70 [============================>.] - ETA: 0s - loss: 2.0371e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 68ms/step - loss: 2.0342e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9693
# Epoch 29/100
# 69/70 [============================>.] - ETA: 0s - loss: 8.5377e-05 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 68ms/step - loss: 8.5501e-05 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9684
# Epoch 30/100
# 69/70 [============================>.] - ETA: 0s - loss: 8.5119e-05 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 68ms/step - loss: 1.0897e-04 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9711
# Epoch 31/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9991
# Epoch 31: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.2632 - val_accuracy: 0.9639
# Epoch 32/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1332 - accuracy: 0.9620
# Epoch 32: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 67ms/step - loss: 0.1329 - accuracy: 0.9620 - val_loss: 0.5757 - val_accuracy: 0.8645
# Epoch 33/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9839
# Epoch 33: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0475 - accuracy: 0.9837 - val_loss: 0.6418 - val_accuracy: 0.9341
# Epoch 34/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0384 - accuracy: 0.9857
# Epoch 34: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0406 - accuracy: 0.9855 - val_loss: 5.2273 - val_accuracy: 0.6432
# Epoch 35/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0807 - accuracy: 0.9760
# Epoch 35: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0805 - accuracy: 0.9760 - val_loss: 0.4127 - val_accuracy: 0.8744
# Epoch 36/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0255 - accuracy: 0.9907
# Epoch 36: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0262 - accuracy: 0.9905 - val_loss: 0.2816 - val_accuracy: 0.9566
# Epoch 37/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0464 - accuracy: 0.9857
# Epoch 37: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0464 - accuracy: 0.9858 - val_loss: 1.6888 - val_accuracy: 0.8744
# Epoch 38/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9968
# Epoch 38: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.1709 - val_accuracy: 0.9702
# Epoch 39/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9993
# Epoch 39: val_accuracy improved from 0.97200 to 0.97290, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.1034 - val_accuracy: 0.9729
# Epoch 40/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9995
# Epoch 40: val_accuracy did not improve from 0.97290
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.1022 - val_accuracy: 0.9666
# Epoch 41/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0271 - accuracy: 0.9941
# Epoch 41: val_accuracy did not improve from 0.97290
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0272 - accuracy: 0.9941 - val_loss: 6.9881 - val_accuracy: 0.4779
# Epoch 42/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9882
# Epoch 42: val_accuracy did not improve from 0.97290
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0387 - accuracy: 0.9882 - val_loss: 2.5029 - val_accuracy: 0.8428
# Epoch 43/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9980
# Epoch 43: val_accuracy improved from 0.97290 to 0.97561, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.1138 - val_accuracy: 0.9756
# Epoch 44/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9989
# Epoch 44: val_accuracy improved from 0.97561 to 0.97742, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.2099 - val_accuracy: 0.9774
# Epoch 45/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 45: val_accuracy improved from 0.97742 to 0.98193, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1092 - val_accuracy: 0.9819
# Epoch 46/100
# 69/70 [============================>.] - ETA: 0s - loss: 3.2044e-04 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.2403 - val_accuracy: 0.9422
# Epoch 47/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1153 - accuracy: 0.9717
# Epoch 47: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 5s 67ms/step - loss: 0.1151 - accuracy: 0.9718 - val_loss: 3.6202 - val_accuracy: 0.4779
# Epoch 48/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 0.9941
# Epoch 48: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0188 - accuracy: 0.9941 - val_loss: 0.1141 - val_accuracy: 0.9584
# Epoch 49/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0091 - accuracy: 0.9971
# Epoch 49: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.1495 - val_accuracy: 0.9612
# Epoch 50/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9948
# Epoch 50: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0138 - accuracy: 0.9941 - val_loss: 0.1444 - val_accuracy: 0.9530
# Epoch 51/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0963 - accuracy: 0.9731
# Epoch 51: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0964 - accuracy: 0.9729 - val_loss: 1.0551 - val_accuracy: 0.7787
# Epoch 52/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0239 - accuracy: 0.9912
# Epoch 52: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0245 - accuracy: 0.9910 - val_loss: 0.7642 - val_accuracy: 0.7977
# Epoch 53/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0642 - accuracy: 0.9780
# Epoch 53: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0641 - accuracy: 0.9781 - val_loss: 31.0005 - val_accuracy: 0.5357
# Epoch 54/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9973
# Epoch 54: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.5677 - val_accuracy: 0.8428
# Epoch 55/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9882
# Epoch 55: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 5s 66ms/step - loss: 0.0340 - accuracy: 0.9882 - val_loss: 0.1720 - val_accuracy: 0.9693
# Epoch 56/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0108 - accuracy: 0.9964
# Epoch 56: val_accuracy improved from 0.98193 to 0.98464, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.1021 - val_accuracy: 0.9846
# Epoch 57/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9898
# Epoch 57: val_accuracy did not improve from 0.98464
# 70/70 [==============================] - 5s 66ms/step - loss: 0.0236 - accuracy: 0.9898 - val_loss: 0.1504 - val_accuracy: 0.9621
# Epoch 58/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9939
# Epoch 58: val_accuracy did not improve from 0.98464
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0160 - accuracy: 0.9939 - val_loss: 3.6484 - val_accuracy: 0.7742
# Epoch 59/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 0.9964
# Epoch 59: val_accuracy did not improve from 0.98464
# 70/70 [==============================] - 5s 69ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0913 - val_accuracy: 0.9801
# Epoch 60/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9993
# Epoch 60: val_accuracy did not improve from 0.98464
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0638 - val_accuracy: 0.9846
# Epoch 61/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9995
# Epoch 61: val_accuracy improved from 0.98464 to 0.98645, saving model to best_model.h5
# 70/70 [==============================] - 5s 76ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0777 - val_accuracy: 0.9864
# Epoch 62/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9989
# Epoch 62: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.0859 - val_accuracy: 0.9783
# Epoch 63/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 0.9916
# Epoch 63: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0223 - accuracy: 0.9916 - val_loss: 2.1382 - val_accuracy: 0.7507
# Epoch 64/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0394 - accuracy: 0.9903
# Epoch 64: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0394 - accuracy: 0.9903 - val_loss: 66.0451 - val_accuracy: 0.2556
# Epoch 65/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0180 - accuracy: 0.9959
# Epoch 65: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0182 - accuracy: 0.9957 - val_loss: 0.3434 - val_accuracy: 0.9368
# Epoch 66/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9955
# Epoch 66: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 66ms/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.1486 - val_accuracy: 0.9783
# Epoch 67/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0250 - accuracy: 0.9928
# Epoch 67: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 66ms/step - loss: 0.0249 - accuracy: 0.9928 - val_loss: 0.0919 - val_accuracy: 0.9855
# Epoch 68/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.9971
# Epoch 68: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0101 - accuracy: 0.9971 - val_loss: 0.3120 - val_accuracy: 0.9359
# Epoch 69/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9957
# Epoch 69: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0118 - accuracy: 0.9957 - val_loss: 0.0548 - val_accuracy: 0.9837
# Epoch 70/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.9984
# Epoch 70: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0032 - accuracy: 0.9984 - val_loss: 0.1482 - val_accuracy: 0.9702
# Epoch 71/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9991
# Epoch 71: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.5744 - val_accuracy: 0.9440
# Epoch 72/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 72: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0948 - val_accuracy: 0.9792
# Epoch 73/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9993
# Epoch 73: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.1022 - val_accuracy: 0.9720
# Epoch 74/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9984
# Epoch 74: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 19.0376 - val_accuracy: 0.5971
# Epoch 75/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9973
# Epoch 75: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.1939 - val_accuracy: 0.9621
# Epoch 76/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9968
# Epoch 76: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.1965 - val_accuracy: 0.9648
# Epoch 77/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0416 - accuracy: 0.9882
# Epoch 77: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0415 - accuracy: 0.9882 - val_loss: 1.3102 - val_accuracy: 0.7498
# Epoch 78/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0099 - accuracy: 0.9973
# Epoch 78: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0099 - accuracy: 0.9973 - val_loss: 0.2979 - val_accuracy: 0.9539
# Epoch 79/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0215 - accuracy: 0.9932
# Epoch 79: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0215 - accuracy: 0.9932 - val_loss: 0.2114 - val_accuracy: 0.9675
# Epoch 80/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9962
# Epoch 80: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.2645 - val_accuracy: 0.9485
# Epoch 81/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9932
# Epoch 81: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0160 - accuracy: 0.9932 - val_loss: 1.2574 - val_accuracy: 0.8067
# Epoch 82/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9973
# Epoch 82: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.6483 - val_accuracy: 0.8266
# Epoch 83/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9989
# Epoch 83: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.1424 - val_accuracy: 0.9584
# Epoch 84/100
# 69/70 [============================>.] - ETA: 0s - loss: 4.1658e-04 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 67ms/step - loss: 4.1641e-04 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 0.9774
# Epoch 85/100
# 69/70 [============================>.] - ETA: 0s - loss: 1.9467e-04 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 5s 69ms/step - loss: 1.9469e-04 - accuracy: 1.0000 - val_loss: 0.0546 - val_accuracy: 0.9846
# Epoch 86/100
# 69/70 [============================>.] - ETA: 0s - loss: 9.5526e-05 - accuracy: 1.0000
# Epoch 86: val_accuracy improved from 0.98645 to 0.98735, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 9.5364e-05 - accuracy: 1.0000 - val_loss: 0.0502 - val_accuracy: 0.9874
# Epoch 87/100
# 69/70 [============================>.] - ETA: 0s - loss: 3.2451e-04 - accuracy: 1.0000
# Epoch 87: val_accuracy improved from 0.98735 to 0.99006, saving model to best_model.h5
# 70/70 [==============================] - 5s 77ms/step - loss: 3.2406e-04 - accuracy: 1.0000 - val_loss: 0.0528 - val_accuracy: 0.9901
# Epoch 88/100
# 69/70 [============================>.] - ETA: 0s - loss: 2.2408e-04 - accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0197 - accuracy: 0.9993 - val_loss: 17.6183 - val_accuracy: 0.4833
# Epoch 89/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1926 - accuracy: 0.9432
# Epoch 89: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 66ms/step - loss: 0.1931 - accuracy: 0.9431 - val_loss: 313.7507 - val_accuracy: 0.2547
# Epoch 90/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9805
# Epoch 90: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0542 - accuracy: 0.9803 - val_loss: 5.6175 - val_accuracy: 0.3975
# Epoch 91/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9740
# Epoch 91: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0832 - accuracy: 0.9738 - val_loss: 1.0813 - val_accuracy: 0.7398
# Epoch 92/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0255 - accuracy: 0.9903
# Epoch 92: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0257 - accuracy: 0.9901 - val_loss: 0.3894 - val_accuracy: 0.9088
# Epoch 93/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0212 - accuracy: 0.9923
# Epoch 93: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 1.1165 - val_accuracy: 0.8257
# Epoch 94/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9903
# Epoch 94: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0295 - accuracy: 0.9903 - val_loss: 1.0373 - val_accuracy: 0.7606
# Epoch 95/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9975
# Epoch 95: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.1684 - val_accuracy: 0.9566
# Epoch 96/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0236 - accuracy: 0.9943
# Epoch 96: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0236 - accuracy: 0.9944 - val_loss: 0.0782 - val_accuracy: 0.9792
# Epoch 97/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.9977
# Epoch 97: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0726 - val_accuracy: 0.9837
# Epoch 98/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9984
# Epoch 98: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 66ms/step - loss: 0.0043 - accuracy: 0.9982 - val_loss: 0.0913 - val_accuracy: 0.9756
# Epoch 99/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9984
# Epoch 99: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.1168 - val_accuracy: 0.9738
# Epoch 100/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0445 - accuracy: 0.9871
# Epoch 100: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0445 - accuracy: 0.9871 - val_loss: 0.0861 - val_accuracy: 0.9828

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 35/35 [==============================] - 2s 14ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("ShuffleNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# ShuffleNet MODEL SONUÇLARI
# Doğruluk:  0.990063233965673
# F1_Skor:  0.9902440054774297
# Hassasiyet:  0.9902359814490775
# Duyarlılık:  0.990359817487477

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# [[277   6   2   1]
#  [  2 280   0   0]
#  [  0   0 283   0]
#  [  0   0   0 256]]
# <Axes: >
