# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 4062 images belonging to 4 classes.
# (4062, 224, 224, 3)
# (4062, 4)

# %%
#Converting  our color images to a vector
x=x.reshape(4062,224*224*3)

# %%
x.shape
# Out:
# (4062, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape

# %%
X_smote=X_smote.reshape(5532,224,224,3)

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')

# %%
"""
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
data_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
"""
# Out:
# "\ndisease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']\ndata_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'\ntrain_dir = os.path.join(data_dir)\n\ntrain_data = []\nfor defects_id, sp in enumerate(disease_types):\n    for file in os.listdir(os.path.join(train_dir, sp)):\n        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])\n\ntrain = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])\n\nSEED = 42\ntrain = train.sample(frac=1, random_state=SEED)\ntrain.index = np.arange(len(train)) # Reset indices\n"

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (5532, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
from keras.applications.densenet import DenseNet121
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    x = densenet(x)
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(4,activation = 'softmax', name='root')(x)

    # model
    model = Model(input,output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
model_dense = build_densenet()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 3)       84
#
#  densenet121 (Functional)    (None, None, None, 1024   7037504
#                              )
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  batch_normalization (Batch  (None, 1024)              4096
#  Normalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 4)                 1028
#
# =================================================================
# Total params: 7306136 (27.87 MB)
# Trainable params: 7219928 (27.54 MB)
# Non-trainable params: 86208 (336.75 KB)
# _________________________________________________________________

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist_dense=model_dense.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 70/70 [==============================] - ETA: 0s - loss: 0.4491 - accuracy: 0.8373
# Epoch 1: val_accuracy improved from -inf to 0.31436, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 70/70 [==============================] - 130s 816ms/step - loss: 0.4491 - accuracy: 0.8373 - val_loss: 1.6562 - val_accuracy: 0.3144
# Epoch 2/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9842
# Epoch 2: val_accuracy improved from 0.31436 to 0.49232, saving model to best_model.h5
# 70/70 [==============================] - 51s 734ms/step - loss: 0.0510 - accuracy: 0.9842 - val_loss: 1.2233 - val_accuracy: 0.4923
# Epoch 3/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9925
# Epoch 3: val_accuracy improved from 0.49232 to 0.79584, saving model to best_model.h5
# 70/70 [==============================] - 52s 742ms/step - loss: 0.0262 - accuracy: 0.9925 - val_loss: 0.4919 - val_accuracy: 0.7958
# Epoch 4/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9948
# Epoch 4: val_accuracy improved from 0.79584 to 0.93315, saving model to best_model.h5
# 70/70 [==============================] - 52s 741ms/step - loss: 0.0193 - accuracy: 0.9948 - val_loss: 0.1673 - val_accuracy: 0.9332
# Epoch 5/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9993
# Epoch 5: val_accuracy improved from 0.93315 to 0.98193, saving model to best_model.h5
# 70/70 [==============================] - 52s 741ms/step - loss: 0.0051 - accuracy: 0.9993 - val_loss: 0.0497 - val_accuracy: 0.9819
# Epoch 6/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9962
# Epoch 6: val_accuracy improved from 0.98193 to 0.99097, saving model to best_model.h5
# 70/70 [==============================] - 52s 741ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0266 - val_accuracy: 0.9910
# Epoch 7/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9966
# Epoch 7: val_accuracy improved from 0.99097 to 0.99458, saving model to best_model.h5
# 70/70 [==============================] - 52s 742ms/step - loss: 0.0138 - accuracy: 0.9966 - val_loss: 0.0222 - val_accuracy: 0.9946
# Epoch 8/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9989
# Epoch 8: val_accuracy did not improve from 0.99458
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0055 - accuracy: 0.9989 - val_loss: 0.0155 - val_accuracy: 0.9928
# Epoch 9/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9991
# Epoch 9: val_accuracy did not improve from 0.99458
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.0113 - val_accuracy: 0.9946
# Epoch 10/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9989
# Epoch 10: val_accuracy improved from 0.99458 to 0.99819, saving model to best_model.h5
# 70/70 [==============================] - 52s 741ms/step - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.0065 - val_accuracy: 0.9982
# Epoch 11/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9991
# Epoch 11: val_accuracy did not improve from 0.99819
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0051 - val_accuracy: 0.9973
# Epoch 12/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9991
# Epoch 12: val_accuracy did not improve from 0.99819
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0062 - val_accuracy: 0.9982
# Epoch 13/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 13: val_accuracy did not improve from 0.99819
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0071 - val_accuracy: 0.9982
# Epoch 14/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9998
# Epoch 14: val_accuracy did not improve from 0.99819
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.0045 - val_accuracy: 0.9973
# Epoch 15/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9993
# Epoch 15: val_accuracy improved from 0.99819 to 0.99910, saving model to best_model.h5
# 70/70 [==============================] - 52s 746ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.0047 - val_accuracy: 0.9991
# Epoch 16/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9959
# Epoch 16: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.0083 - val_accuracy: 0.9973
# Epoch 17/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9980
# Epoch 17: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0043 - accuracy: 0.9980 - val_loss: 0.0084 - val_accuracy: 0.9973
# Epoch 18/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9984
# Epoch 18: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 725ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.0102 - val_accuracy: 0.9973
# Epoch 19/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9964
# Epoch 19: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 725ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.0066 - val_accuracy: 0.9982
# Epoch 20/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9950
# Epoch 20: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0124 - val_accuracy: 0.9955
# Epoch 21/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9993
# Epoch 21: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.0101 - val_accuracy: 0.9973
# Epoch 22/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9998
# Epoch 22: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.0110 - val_accuracy: 0.9964
# Epoch 23/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 23: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0153 - val_accuracy: 0.9964
# Epoch 24/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9989
# Epoch 24: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0267 - val_accuracy: 0.9937
# Epoch 25/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9957
# Epoch 25: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0143 - accuracy: 0.9957 - val_loss: 0.0423 - val_accuracy: 0.9901
# Epoch 26/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9995
# Epoch 26: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.0046 - val_accuracy: 0.9982
# Epoch 27/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9995
# Epoch 27: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0047 - val_accuracy: 0.9973
# Epoch 28/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 28: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0024 - val_accuracy: 0.9991
# Epoch 29/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 29: val_accuracy improved from 0.99910 to 1.00000, saving model to best_model.h5
# 70/70 [==============================] - 52s 741ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 30/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9998
# Epoch 30: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0043 - val_accuracy: 0.9982
# Epoch 31/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 31: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0021 - val_accuracy: 0.9991
# Epoch 32/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9993
# Epoch 32: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 33/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 33: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 9.6558e-04 - val_accuracy: 1.0000
# Epoch 34/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9993
# Epoch 34: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 0.0025 - val_accuracy: 0.9991
# Epoch 35/100
# 70/70 [==============================] - ETA: 0s - loss: 3.3794e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 3.3794e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9982
# Epoch 36/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9995
# Epoch 36: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 5.5804e-04 - val_accuracy: 1.0000
# Epoch 37/100
# 70/70 [==============================] - ETA: 0s - loss: 6.0344e-04 - accuracy: 0.9998
# Epoch 37: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 6.0344e-04 - accuracy: 0.9998 - val_loss: 0.0011 - val_accuracy: 0.9991
# Epoch 38/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9982
# Epoch 38: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0103 - accuracy: 0.9982 - val_loss: 0.0057 - val_accuracy: 0.9982
# Epoch 39/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9896
# Epoch 39: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0342 - accuracy: 0.9896 - val_loss: 0.1300 - val_accuracy: 0.9666
# Epoch 40/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9991
# Epoch 40: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0162 - val_accuracy: 0.9955
# Epoch 41/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9993
# Epoch 41: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.0137 - val_accuracy: 0.9946
# Epoch 42/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9991
# Epoch 42: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0049 - val_accuracy: 0.9964
# Epoch 43/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9993
# Epoch 43: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0045 - val_accuracy: 0.9982
# Epoch 44/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9995
# Epoch 44: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0050 - accuracy: 0.9995 - val_loss: 0.0033 - val_accuracy: 0.9991
# Epoch 45/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9937
# Epoch 45: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0209 - accuracy: 0.9937 - val_loss: 0.0091 - val_accuracy: 0.9955
# Epoch 46/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9993
# Epoch 46: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0046 - accuracy: 0.9993 - val_loss: 0.0107 - val_accuracy: 0.9955
# Epoch 47/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 47: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0189 - val_accuracy: 0.9946
# Epoch 48/100
# 70/70 [==============================] - ETA: 0s - loss: 7.8848e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 7.8848e-04 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9946
# Epoch 49/100
# 70/70 [==============================] - ETA: 0s - loss: 6.9971e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 6.9971e-04 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9946
# Epoch 50/100
# 70/70 [==============================] - ETA: 0s - loss: 7.3649e-04 - accuracy: 0.9995
# Epoch 50: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 7.3649e-04 - accuracy: 0.9995 - val_loss: 0.0089 - val_accuracy: 0.9955
# Epoch 51/100
# 70/70 [==============================] - ETA: 0s - loss: 5.4923e-04 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 5.4923e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 0.9982
# Epoch 52/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 52: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0058 - val_accuracy: 0.9982
# Epoch 53/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9993
# Epoch 53: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0035 - val_accuracy: 0.9982
# Epoch 54/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9991
# Epoch 54: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0035 - val_accuracy: 0.9973
# Epoch 55/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9955
# Epoch 55: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.0192 - val_accuracy: 0.9937
# Epoch 56/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9984
# Epoch 56: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0072 - accuracy: 0.9984 - val_loss: 0.0188 - val_accuracy: 0.9946
# Epoch 57/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9962
# Epoch 57: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.0056 - val_accuracy: 0.9982
# Epoch 58/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9989
# Epoch 58: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0066 - val_accuracy: 0.9973
# Epoch 59/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 59: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0023 - val_accuracy: 0.9991
# Epoch 60/100
# 70/70 [==============================] - ETA: 0s - loss: 8.7729e-04 - accuracy: 0.9998
# Epoch 60: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 8.7729e-04 - accuracy: 0.9998 - val_loss: 0.0024 - val_accuracy: 0.9991
# Epoch 61/100
# 70/70 [==============================] - ETA: 0s - loss: 6.9388e-04 - accuracy: 0.9998
# Epoch 61: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 6.9388e-04 - accuracy: 0.9998 - val_loss: 0.0057 - val_accuracy: 0.9982
# Epoch 62/100
# 70/70 [==============================] - ETA: 0s - loss: 7.9294e-04 - accuracy: 0.9998
# Epoch 62: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 7.9294e-04 - accuracy: 0.9998 - val_loss: 0.0241 - val_accuracy: 0.9937
# Epoch 63/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9991
# Epoch 63: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.0027 - val_accuracy: 0.9991
# Epoch 64/100
# 70/70 [==============================] - ETA: 0s - loss: 8.7407e-04 - accuracy: 0.9998
# Epoch 64: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 8.7407e-04 - accuracy: 0.9998 - val_loss: 0.0023 - val_accuracy: 0.9991
# Epoch 65/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9966
# Epoch 65: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.0342 - val_accuracy: 0.9928
# Epoch 66/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9950
# Epoch 66: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.0248 - val_accuracy: 0.9919
# Epoch 67/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9991
# Epoch 67: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 68/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9995
# Epoch 68: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0059 - val_accuracy: 0.9982
# Epoch 69/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9925
# Epoch 69: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0226 - accuracy: 0.9925 - val_loss: 0.2154 - val_accuracy: 0.9467
# Epoch 70/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9991
# Epoch 70: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0056 - accuracy: 0.9991 - val_loss: 0.0131 - val_accuracy: 0.9955
# Epoch 71/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9962
# Epoch 71: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0163 - val_accuracy: 0.9937
# Epoch 72/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9957
# Epoch 72: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0130 - accuracy: 0.9957 - val_loss: 0.0119 - val_accuracy: 0.9964
# Epoch 73/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9980
# Epoch 73: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.0467 - val_accuracy: 0.9883
# Epoch 74/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9984
# Epoch 74: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0151 - val_accuracy: 0.9955
# Epoch 75/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995
# Epoch 75: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0039 - val_accuracy: 0.9991
# Epoch 76/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9955
# Epoch 76: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.0274 - val_accuracy: 0.9928
# Epoch 77/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9971
# Epoch 77: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0071 - accuracy: 0.9971 - val_loss: 0.0048 - val_accuracy: 0.9964
# Epoch 78/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9989
# Epoch 78: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0068 - val_accuracy: 0.9982
# Epoch 79/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9989
# Epoch 79: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0024 - val_accuracy: 0.9991
# Epoch 80/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9993
# Epoch 80: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0026 - val_accuracy: 0.9982
# Epoch 81/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9995
# Epoch 81: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0027 - val_accuracy: 0.9991
# Epoch 82/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9975
# Epoch 82: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0108 - accuracy: 0.9975 - val_loss: 0.0137 - val_accuracy: 0.9964
# Epoch 83/100
# 70/70 [==============================] - ETA: 0s - loss: 9.4181e-04 - accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 9.4181e-04 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 0.9982
# Epoch 84/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 84: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0034 - val_accuracy: 0.9991
# Epoch 85/100
# 70/70 [==============================] - ETA: 0s - loss: 5.6737e-04 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 5.6737e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 0.9991
# Epoch 86/100
# 70/70 [==============================] - ETA: 0s - loss: 8.2697e-04 - accuracy: 0.9998
# Epoch 86: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 8.2697e-04 - accuracy: 0.9998 - val_loss: 0.0025 - val_accuracy: 0.9991
# Epoch 87/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 87: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0013 - val_accuracy: 0.9991
# Epoch 88/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9989
# Epoch 88: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.0141 - val_accuracy: 0.9946
# Epoch 89/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9993
# Epoch 89: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.0046 - val_accuracy: 0.9982
# Epoch 90/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9993
# Epoch 90: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.0060 - val_accuracy: 0.9991
# Epoch 91/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9977
# Epoch 91: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0166 - val_accuracy: 0.9946
# Epoch 92/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9993
# Epoch 92: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0013 - val_accuracy: 0.9991
# Epoch 93/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 93: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0028 - val_accuracy: 0.9991
# Epoch 94/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 94: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 727ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0042 - val_accuracy: 0.9982
# Epoch 95/100
# 70/70 [==============================] - ETA: 0s - loss: 5.5275e-04 - accuracy: 0.9998
# Epoch 95: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 725ms/step - loss: 5.5275e-04 - accuracy: 0.9998 - val_loss: 0.0030 - val_accuracy: 0.9982
# Epoch 96/100
# 70/70 [==============================] - ETA: 0s - loss: 2.3372e-04 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 2.3372e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 0.9991
# Epoch 97/100
# 70/70 [==============================] - ETA: 0s - loss: 2.3302e-04 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 2.3302e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9991
# Epoch 98/100
# 70/70 [==============================] - ETA: 0s - loss: 5.6950e-04 - accuracy: 0.9998
# Epoch 98: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 5.6950e-04 - accuracy: 0.9998 - val_loss: 0.0044 - val_accuracy: 0.9991
# Epoch 99/100
# 70/70 [==============================] - ETA: 0s - loss: 2.3490e-04 - accuracy: 1.0000
# Epoch 99: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 2.3490e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9991
# Epoch 100/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9993
# Epoch 100: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 51s 726ms/step - loss: 0.0066 - accuracy: 0.9993 - val_loss: 0.0123 - val_accuracy: 0.9973

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 35/35 [==============================] - 5s 94ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("DenseNet121 MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# DenseNet121 MODEL SONUÇLARI
# Doğruluk:  1.0
# F1_Skor:  1.0
# Hassasiyet:  1.0
# Duyarlılık:  1.0

# %%
# DenseNet121 accuracy plot
plt.plot(hist_dense.history['accuracy'])
plt.plot(hist_dense.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# DenseNet121 loss plot
plt.plot(hist_dense.history['loss'])
plt.plot(hist_dense.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# [[286   0   0   0]
#  [  0 282   0   0]
#  [  0   0 283   0]
#  [  0   0   0 256]]
# <Axes: >
