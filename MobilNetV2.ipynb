# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 4062 images belonging to 4 classes.
# (4062, 224, 224, 3)
# (4062, 4)

# %%
#Converting  our color images to a vector
x=x.reshape(4062,224*224*3)

# %%
x.shape
# Out:
# (4062, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (5532, 150528)

# %%
X_smote=X_smote.reshape(5532,224,224,3)

# %% [markdown]
# # 1. sınıf: 1179  2. sınıf: 1076 3. sınıf: 1142 4. sınıf: 1180

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (4062, 150528)
# Shape of X after SMOTE: (5532, 224, 224, 3)

# %%
"""
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
data_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
"""
# Out:
# "\ndisease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']\ndata_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'\ntrain_dir = os.path.join(data_dir)\n\ntrain_data = []\nfor defects_id, sp in enumerate(disease_types):\n    for file in os.listdir(os.path.join(train_dir, sp)):\n        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])\n\ntrain = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])\n\nSEED = 42\ntrain = train.sample(frac=1, random_state=SEED)\ntrain.index = np.arange(len(train)) # Reset indices\n"

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (5532, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
from keras.applications import MobileNetV2
def build_MobilNetV2():
    mobilnetv2 = MobileNetV2(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    x = mobilnetv2(x)
    x = Flatten(name="flatten")(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    # multi output
    output = Dense(4,activation = 'softmax', name='root')(x)
    # model
    model = Model(input,output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
model_mobilnet=build_MobilNetV2()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 3)       84
#
#  mobilenetv2_1.00_224 (Func  (None, None, None, 1280   2257984
#  tional)                     )
#
#  flatten (Flatten)           (None, 62720)             0
#
#  dropout (Dropout)           (None, 62720)             0
#
#  dense (Dense)               (None, 256)               16056576
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 4)                 1028
#
# =================================================================
# Total params: 18316696 (69.87 MB)
# Trainable params: 18282072 (69.74 MB)
# Non-trainable params: 34624 (135.25 KB)
# _________________________________________________________________

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist_mobilnetv1=model_mobilnet.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 70/70 [==============================] - ETA: 0s - loss: 0.3398 - accuracy: 0.8902
# Epoch 1: val_accuracy improved from -inf to 0.31527, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 70/70 [==============================] - 58s 335ms/step - loss: 0.3398 - accuracy: 0.8902 - val_loss: 5.0879 - val_accuracy: 0.3153
# Epoch 2/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9855
# Epoch 2: val_accuracy did not improve from 0.31527
# 70/70 [==============================] - 20s 280ms/step - loss: 0.0434 - accuracy: 0.9855 - val_loss: 6.3211 - val_accuracy: 0.2692
# Epoch 3/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9962
# Epoch 3: val_accuracy did not improve from 0.31527
# 70/70 [==============================] - 20s 284ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 6.0122 - val_accuracy: 0.2502
# Epoch 4/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9966
# Epoch 4: val_accuracy did not improve from 0.31527
# 70/70 [==============================] - 20s 289ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 5.7733 - val_accuracy: 0.2421
# Epoch 5/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9971
# Epoch 5: val_accuracy did not improve from 0.31527
# 70/70 [==============================] - 20s 290ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 5.8619 - val_accuracy: 0.2484
# Epoch 6/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9986
# Epoch 6: val_accuracy did not improve from 0.31527
# 70/70 [==============================] - 20s 287ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 5.0478 - val_accuracy: 0.2502
# Epoch 7/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9986
# Epoch 7: val_accuracy did not improve from 0.31527
# 70/70 [==============================] - 20s 287ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 4.4520 - val_accuracy: 0.2556
# Epoch 8/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9980
# Epoch 8: val_accuracy did not improve from 0.31527
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0047 - accuracy: 0.9980 - val_loss: 4.3840 - val_accuracy: 0.2972
# Epoch 9/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9989
# Epoch 9: val_accuracy improved from 0.31527 to 0.33153, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 3.7013 - val_accuracy: 0.3315
# Epoch 10/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9989
# Epoch 10: val_accuracy did not improve from 0.33153
# 70/70 [==============================] - 20s 289ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 5.0286 - val_accuracy: 0.2782
# Epoch 11/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9971
# Epoch 11: val_accuracy did not improve from 0.33153
# 70/70 [==============================] - 20s 289ms/step - loss: 0.0115 - accuracy: 0.9971 - val_loss: 4.3295 - val_accuracy: 0.2565
# Epoch 12/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9968
# Epoch 12: val_accuracy improved from 0.33153 to 0.39837, saving model to best_model.h5
# 70/70 [==============================] - 21s 301ms/step - loss: 0.0121 - accuracy: 0.9968 - val_loss: 2.3580 - val_accuracy: 0.3984
# Epoch 13/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9993
# Epoch 13: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 4.0159 - val_accuracy: 0.3550
# Epoch 14/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9998
# Epoch 14: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 4.6987 - val_accuracy: 0.3026
# Epoch 15/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 15: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 4.4458 - val_accuracy: 0.2800
# Epoch 16/100
# 70/70 [==============================] - ETA: 0s - loss: 9.2111e-04 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 288ms/step - loss: 9.2111e-04 - accuracy: 1.0000 - val_loss: 4.4882 - val_accuracy: 0.2692
# Epoch 17/100
# 70/70 [==============================] - ETA: 0s - loss: 6.2660e-04 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 288ms/step - loss: 6.2660e-04 - accuracy: 1.0000 - val_loss: 4.3392 - val_accuracy: 0.2602
# Epoch 18/100
# 70/70 [==============================] - ETA: 0s - loss: 8.0979e-04 - accuracy: 0.9995
# Epoch 18: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 289ms/step - loss: 8.0979e-04 - accuracy: 0.9995 - val_loss: 4.1769 - val_accuracy: 0.2575
# Epoch 19/100
# 70/70 [==============================] - ETA: 0s - loss: 7.4705e-04 - accuracy: 0.9998
# Epoch 19: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 288ms/step - loss: 7.4705e-04 - accuracy: 0.9998 - val_loss: 4.3698 - val_accuracy: 0.2575
# Epoch 20/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 20: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 5.0538 - val_accuracy: 0.2385
# Epoch 21/100
# 70/70 [==============================] - ETA: 0s - loss: 5.2908e-04 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 289ms/step - loss: 5.2908e-04 - accuracy: 1.0000 - val_loss: 5.0583 - val_accuracy: 0.2484
# Epoch 22/100
# 70/70 [==============================] - ETA: 0s - loss: 5.5706e-04 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 288ms/step - loss: 5.5706e-04 - accuracy: 1.0000 - val_loss: 5.0288 - val_accuracy: 0.2475
# Epoch 23/100
# 70/70 [==============================] - ETA: 0s - loss: 8.9526e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 288ms/step - loss: 8.9526e-04 - accuracy: 1.0000 - val_loss: 4.6911 - val_accuracy: 0.2584
# Epoch 24/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9982
# Epoch 24: val_accuracy did not improve from 0.39837
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 4.1737 - val_accuracy: 0.2629
# Epoch 25/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9944
# Epoch 25: val_accuracy improved from 0.39837 to 0.43360, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0181 - accuracy: 0.9944 - val_loss: 3.3567 - val_accuracy: 0.4336
# Epoch 26/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9984
# Epoch 26: val_accuracy did not improve from 0.43360
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0032 - accuracy: 0.9984 - val_loss: 3.5586 - val_accuracy: 0.3767
# Epoch 27/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 27: val_accuracy did not improve from 0.43360
# 70/70 [==============================] - 20s 289ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 3.1969 - val_accuracy: 0.4300
# Epoch 28/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 28: val_accuracy did not improve from 0.43360
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 3.3829 - val_accuracy: 0.4092
# Epoch 29/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9980
# Epoch 29: val_accuracy improved from 0.43360 to 0.46432, saving model to best_model.h5
# 70/70 [==============================] - 21s 301ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 3.5955 - val_accuracy: 0.4643
# Epoch 30/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9984
# Epoch 30: val_accuracy did not improve from 0.46432
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0079 - accuracy: 0.9984 - val_loss: 3.8794 - val_accuracy: 0.4634
# Epoch 31/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9885
# Epoch 31: val_accuracy did not improve from 0.46432
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0462 - accuracy: 0.9885 - val_loss: 5.2652 - val_accuracy: 0.4327
# Epoch 32/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9986
# Epoch 32: val_accuracy did not improve from 0.46432
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 4.1935 - val_accuracy: 0.4408
# Epoch 33/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9986
# Epoch 33: val_accuracy did not improve from 0.46432
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 3.1446 - val_accuracy: 0.4444
# Epoch 34/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9995
# Epoch 34: val_accuracy improved from 0.46432 to 0.46522, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 3.3444 - val_accuracy: 0.4652
# Epoch 35/100
# 70/70 [==============================] - ETA: 0s - loss: 6.2231e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy improved from 0.46522 to 0.46883, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 6.2231e-04 - accuracy: 1.0000 - val_loss: 3.1848 - val_accuracy: 0.4688
# Epoch 36/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 36: val_accuracy did not improve from 0.46883
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 3.5590 - val_accuracy: 0.4544
# Epoch 37/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9991
# Epoch 37: val_accuracy did not improve from 0.46883
# 70/70 [==============================] - 20s 289ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 3.5149 - val_accuracy: 0.4092
# Epoch 38/100
# 70/70 [==============================] - ETA: 0s - loss: 8.5963e-04 - accuracy: 0.9998
# Epoch 38: val_accuracy did not improve from 0.46883
# 70/70 [==============================] - 20s 288ms/step - loss: 8.5963e-04 - accuracy: 0.9998 - val_loss: 3.9761 - val_accuracy: 0.4092
# Epoch 39/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9989
# Epoch 39: val_accuracy did not improve from 0.46883
# 70/70 [==============================] - 20s 289ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 3.5258 - val_accuracy: 0.4426
# Epoch 40/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 40: val_accuracy did not improve from 0.46883
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 4.7966 - val_accuracy: 0.4020
# Epoch 41/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9989
# Epoch 41: val_accuracy did not improve from 0.46883
# 70/70 [==============================] - 20s 289ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 4.4500 - val_accuracy: 0.4309
# Epoch 42/100
# 70/70 [==============================] - ETA: 0s - loss: 8.8600e-04 - accuracy: 0.9998
# Epoch 42: val_accuracy did not improve from 0.46883
# 70/70 [==============================] - 20s 289ms/step - loss: 8.8600e-04 - accuracy: 0.9998 - val_loss: 3.7017 - val_accuracy: 0.4444
# Epoch 43/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9993
# Epoch 43: val_accuracy improved from 0.46883 to 0.51220, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 3.0767 - val_accuracy: 0.5122
# Epoch 44/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9993
# Epoch 44: val_accuracy improved from 0.51220 to 0.53117, saving model to best_model.h5
# 70/70 [==============================] - 21s 301ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 2.6190 - val_accuracy: 0.5312
# Epoch 45/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9950
# Epoch 45: val_accuracy did not improve from 0.53117
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0187 - accuracy: 0.9950 - val_loss: 3.1171 - val_accuracy: 0.4580
# Epoch 46/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9989
# Epoch 46: val_accuracy did not improve from 0.53117
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 2.8454 - val_accuracy: 0.5185
# Epoch 47/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9989
# Epoch 47: val_accuracy did not improve from 0.53117
# 70/70 [==============================] - 20s 289ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 2.7382 - val_accuracy: 0.5212
# Epoch 48/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9995
# Epoch 48: val_accuracy improved from 0.53117 to 0.57001, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 2.3293 - val_accuracy: 0.5700
# Epoch 49/100
# 70/70 [==============================] - ETA: 0s - loss: 9.9065e-04 - accuracy: 0.9995
# Epoch 49: val_accuracy improved from 0.57001 to 0.58537, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 9.9065e-04 - accuracy: 0.9995 - val_loss: 2.1839 - val_accuracy: 0.5854
# Epoch 50/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9998
# Epoch 50: val_accuracy improved from 0.58537 to 0.59892, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 1.9545 - val_accuracy: 0.5989
# Epoch 51/100
# 70/70 [==============================] - ETA: 0s - loss: 5.1231e-04 - accuracy: 1.0000
# Epoch 51: val_accuracy improved from 0.59892 to 0.61698, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 5.1231e-04 - accuracy: 1.0000 - val_loss: 1.8221 - val_accuracy: 0.6170
# Epoch 52/100
# 70/70 [==============================] - ETA: 0s - loss: 7.7148e-04 - accuracy: 1.0000
# Epoch 52: val_accuracy improved from 0.61698 to 0.65312, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 7.7148e-04 - accuracy: 1.0000 - val_loss: 1.5030 - val_accuracy: 0.6531
# Epoch 53/100
# 70/70 [==============================] - ETA: 0s - loss: 4.0028e-04 - accuracy: 1.0000
# Epoch 53: val_accuracy improved from 0.65312 to 0.67118, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 4.0028e-04 - accuracy: 1.0000 - val_loss: 1.4134 - val_accuracy: 0.6712
# Epoch 54/100
# 70/70 [==============================] - ETA: 0s - loss: 5.0315e-04 - accuracy: 1.0000
# Epoch 54: val_accuracy improved from 0.67118 to 0.72719, saving model to best_model.h5
# 70/70 [==============================] - 21s 301ms/step - loss: 5.0315e-04 - accuracy: 1.0000 - val_loss: 1.1249 - val_accuracy: 0.7272
# Epoch 55/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9995
# Epoch 55: val_accuracy improved from 0.72719 to 0.75519, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.9727 - val_accuracy: 0.7552
# Epoch 56/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9919
# Epoch 56: val_accuracy improved from 0.75519 to 0.79133, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0289 - accuracy: 0.9919 - val_loss: 1.0671 - val_accuracy: 0.7913
# Epoch 57/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 57: val_accuracy did not improve from 0.79133
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 1.1750 - val_accuracy: 0.7606
# Epoch 58/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 58: val_accuracy improved from 0.79133 to 0.81752, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.7666 - val_accuracy: 0.8175
# Epoch 59/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9980
# Epoch 59: val_accuracy did not improve from 0.81752
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.8221 - val_accuracy: 0.7949
# Epoch 60/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9989
# Epoch 60: val_accuracy did not improve from 0.81752
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 1.3918 - val_accuracy: 0.7145
# Epoch 61/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9993
# Epoch 61: val_accuracy did not improve from 0.81752
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 1.7897 - val_accuracy: 0.6929
# Epoch 62/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9932
# Epoch 62: val_accuracy did not improve from 0.81752
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0252 - accuracy: 0.9932 - val_loss: 2.1700 - val_accuracy: 0.6387
# Epoch 63/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9991
# Epoch 63: val_accuracy did not improve from 0.81752
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 1.3547 - val_accuracy: 0.7245
# Epoch 64/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9959
# Epoch 64: val_accuracy did not improve from 0.81752
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0133 - accuracy: 0.9959 - val_loss: 0.7915 - val_accuracy: 0.8022
# Epoch 65/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9989
# Epoch 65: val_accuracy improved from 0.81752 to 0.89341, saving model to best_model.h5
# 70/70 [==============================] - 21s 301ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.3852 - val_accuracy: 0.8934
# Epoch 66/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9995
# Epoch 66: val_accuracy improved from 0.89341 to 0.92773, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.2551 - val_accuracy: 0.9277
# Epoch 67/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9982
# Epoch 67: val_accuracy improved from 0.92773 to 0.93948, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.2101 - val_accuracy: 0.9395
# Epoch 68/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9959
# Epoch 68: val_accuracy improved from 0.93948 to 0.97742, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0107 - accuracy: 0.9959 - val_loss: 0.0821 - val_accuracy: 0.9774
# Epoch 69/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9991
# Epoch 69: val_accuracy improved from 0.97742 to 0.98735, saving model to best_model.h5
# 70/70 [==============================] - 21s 301ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.0569 - val_accuracy: 0.9874
# Epoch 70/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9991
# Epoch 70: val_accuracy did not improve from 0.98735
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.1018 - val_accuracy: 0.9738
# Epoch 71/100
# 70/70 [==============================] - ETA: 0s - loss: 8.7815e-04 - accuracy: 0.9998
# Epoch 71: val_accuracy did not improve from 0.98735
# 70/70 [==============================] - 20s 289ms/step - loss: 8.7815e-04 - accuracy: 0.9998 - val_loss: 0.0877 - val_accuracy: 0.9765
# Epoch 72/100
# 70/70 [==============================] - ETA: 0s - loss: 8.7944e-04 - accuracy: 0.9998
# Epoch 72: val_accuracy did not improve from 0.98735
# 70/70 [==============================] - 20s 288ms/step - loss: 8.7944e-04 - accuracy: 0.9998 - val_loss: 0.0819 - val_accuracy: 0.9738
# Epoch 73/100
# 70/70 [==============================] - ETA: 0s - loss: 3.1465e-04 - accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 0.98735
# 70/70 [==============================] - 20s 289ms/step - loss: 3.1465e-04 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9810
# Epoch 74/100
# 70/70 [==============================] - ETA: 0s - loss: 7.3467e-04 - accuracy: 0.9998
# Epoch 74: val_accuracy did not improve from 0.98735
# 70/70 [==============================] - 20s 289ms/step - loss: 7.3467e-04 - accuracy: 0.9998 - val_loss: 0.0535 - val_accuracy: 0.9846
# Epoch 75/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 75: val_accuracy improved from 0.98735 to 0.99097, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0273 - val_accuracy: 0.9910
# Epoch 76/100
# 70/70 [==============================] - ETA: 0s - loss: 9.8429e-04 - accuracy: 0.9995
# Epoch 76: val_accuracy improved from 0.99097 to 0.99277, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 9.8429e-04 - accuracy: 0.9995 - val_loss: 0.0270 - val_accuracy: 0.9928
# Epoch 77/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9991
# Epoch 77: val_accuracy improved from 0.99277 to 0.99639, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.0222 - val_accuracy: 0.9964
# Epoch 78/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9995
# Epoch 78: val_accuracy did not improve from 0.99639
# 70/70 [==============================] - 20s 289ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0223 - val_accuracy: 0.9919
# Epoch 79/100
# 70/70 [==============================] - ETA: 0s - loss: 3.7691e-04 - accuracy: 1.0000
# Epoch 79: val_accuracy did not improve from 0.99639
# 70/70 [==============================] - 20s 289ms/step - loss: 3.7691e-04 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 0.9937
# Epoch 80/100
# 70/70 [==============================] - ETA: 0s - loss: 5.4067e-04 - accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 0.99639
# 70/70 [==============================] - 20s 289ms/step - loss: 5.4067e-04 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9946
# Epoch 81/100
# 70/70 [==============================] - ETA: 0s - loss: 3.7140e-04 - accuracy: 1.0000
# Epoch 81: val_accuracy improved from 0.99639 to 0.99819, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 3.7140e-04 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 0.9982
# Epoch 82/100
# 70/70 [==============================] - ETA: 0s - loss: 1.8949e-04 - accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 0.99819
# 70/70 [==============================] - 20s 288ms/step - loss: 1.8949e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9982
# Epoch 83/100
# 70/70 [==============================] - ETA: 0s - loss: 1.7071e-04 - accuracy: 1.0000
# Epoch 83: val_accuracy improved from 0.99819 to 0.99910, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 1.7071e-04 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 0.9991
# Epoch 84/100
# 70/70 [==============================] - ETA: 0s - loss: 3.6440e-04 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 20s 288ms/step - loss: 3.6440e-04 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 0.9991
# Epoch 85/100
# 70/70 [==============================] - ETA: 0s - loss: 1.4133e-04 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 20s 288ms/step - loss: 1.4133e-04 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9991
# Epoch 86/100
# 70/70 [==============================] - ETA: 0s - loss: 1.1454e-04 - accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 20s 289ms/step - loss: 1.1454e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9973
# Epoch 87/100
# 70/70 [==============================] - ETA: 0s - loss: 2.2250e-04 - accuracy: 1.0000
# Epoch 87: val_accuracy improved from 0.99910 to 1.00000, saving model to best_model.h5
# 70/70 [==============================] - 21s 302ms/step - loss: 2.2250e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 88/100
# 70/70 [==============================] - ETA: 0s - loss: 3.8255e-04 - accuracy: 0.9998
# Epoch 88: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 288ms/step - loss: 3.8255e-04 - accuracy: 0.9998 - val_loss: 0.0027 - val_accuracy: 0.9991
# Epoch 89/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9989
# Epoch 89: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0548 - val_accuracy: 0.9828
# Epoch 90/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9989
# Epoch 90: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.0180 - val_accuracy: 0.9946
# Epoch 91/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9998
# Epoch 91: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.0357 - val_accuracy: 0.9919
# Epoch 92/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9991
# Epoch 92: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0017 - accuracy: 0.9991 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 93/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9993
# Epoch 93: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 289ms/step - loss: 0.0048 - accuracy: 0.9993 - val_loss: 6.8358e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9939
# Epoch 94: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0231 - accuracy: 0.9939 - val_loss: 0.0093 - val_accuracy: 0.9973
# Epoch 95/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9993
# Epoch 95: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 289ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0067 - val_accuracy: 0.9964
# Epoch 96/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 96: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0021 - val_accuracy: 0.9991
# Epoch 97/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9953
# Epoch 97: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0120 - accuracy: 0.9953 - val_loss: 0.0090 - val_accuracy: 0.9982
# Epoch 98/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9993
# Epoch 98: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0132 - val_accuracy: 0.9982
# Epoch 99/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9977
# Epoch 99: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.0522 - val_accuracy: 0.9892
# Epoch 100/100
# 70/70 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9982
# Epoch 100: val_accuracy did not improve from 1.00000
# 70/70 [==============================] - 20s 288ms/step - loss: 0.0075 - accuracy: 0.9982 - val_loss: 0.0316 - val_accuracy: 0.9855

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 35/35 [==============================] - 3s 42ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("MobilNetv2 MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred, average='macro'))
print("Hassasiyet: ",precision_score(Y_val, y_pred, average='macro'))
print("Duyarlılık: ", recall_score(Y_val, y_pred, average='macro'))
# Out:
# MobilNetv2 MODEL SONUÇLARI
# Doğruluk:  1.0
# F1_Skor:  1.0
# Hassasiyet:  1.0
# Duyarlılık:  1.0

# %%
plt.plot(hist_mobilnetv1.history['accuracy'])
plt.plot(hist_mobilnetv1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist_mobilnetv1.history['loss'])
plt.plot(hist_mobilnetv1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# [[286   0   0   0]
#  [  0 282   0   0]
#  [  0   0 283   0]
#  [  0   0   0 256]]
# <Axes: >
