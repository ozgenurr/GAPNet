# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 4062 images belonging to 4 classes.
# (4062, 224, 224, 3)
# (4062, 4)

# %%
#Converting  our color images to a vector
x=x.reshape(4062,224*224*3)

# %%
x.shape
# Out:
# (4062, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (5532, 150528)

# %%
X_smote=X_smote.reshape(5532,224,224,3)

# %% [markdown]
# # 1. sınıf: 1179  2. sınıf: 1076 3. sınıf: 1142 4. sınıf: 1180

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (4062, 150528)
# Shape of X after SMOTE: (5532, 224, 224, 3)

# %%
"""
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
data_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
"""
# Out:
# "\ndisease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']\ndata_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'\ntrain_dir = os.path.join(data_dir)\n\ntrain_data = []\nfor defects_id, sp in enumerate(disease_types):\n    for file in os.listdir(os.path.join(train_dir, sp)):\n        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])\n\ntrain = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])\n\nSEED = 42\ntrain = train.sample(frac=1, random_state=SEED)\ntrain.index = np.arange(len(train)) # Reset indices\n"

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (5532, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
pip install keras_applications
# Out:
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications) (3.9.0)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8

# %%
from keras_applications.imagenet_utils import _obtain_input_shape
from keras import backend as K
from keras.layers import Input, Convolution2D, MaxPooling2D, Activation, concatenate, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.models import Model
#from keras.engine.topology import get_source_inputs
from keras.utils import get_file
#from keras.utils import layer_utils

sq1x1 = "squeeze1x1"
exp1x1 = "expand1x1"
exp3x3 = "expand3x3"
relu = "relu_"

WEIGHTS_PATH = "https://github.com/rcmalli/keras-squeezenet/releases/download/v1.0/squeezenet_weights_tf_dim_ordering_tf_kernels.h5"

# Modular function for Fire Node

def fire_module(x, fire_id, squeeze=16, expand=64):
    s_id = 'fire' + str(fire_id) + '/'

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3

    x = Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = Activation('relu', name=s_id + relu + sq1x1)(x)

    left = Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
    left = Activation('relu', name=s_id + relu + exp1x1)(left)

    right = Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
    right = Activation('relu', name=s_id + relu + exp3x3)(right)

    x = concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x


# Original SqueezeNet from paper.

def SqueezeNet(input_tensor=None, input_shape=None,
               weights='imagenet',
               classes=1000,
              use_bn_on_input = False, # to avoid preprocessing
               first_stride = 2
              ):
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')


    input_shape = _obtain_input_shape(input_shape,
                                      default_size=224,
                                      min_size=48,
                                      data_format=K.image_data_format(),
                                     require_flatten = False)

    if input_tensor is None:
        raw_img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    if use_bn_on_input:
        img_input = BatchNormalization()(raw_img_input)
    else:
        img_input = raw_img_input


    x = Convolution2D(64, (3, 3), strides=(first_stride, first_stride), padding='valid', name='conv1')(img_input)
    x = Activation('relu', name='relu_conv1')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5')(x)

    #x = fire_module(x, fire_id=6, squeeze=48, expand=192)
    #x = fire_module(x, fire_id=7, squeeze=48, expand=192)
    #x = fire_module(x, fire_id=8, squeeze=64, expand=256)
    #x = fire_module(x, fire_id=9, squeeze=64, expand=256)
    x = Dropout(0.5, name='drop9')(x)

    x = Convolution2D(classes, (1, 1), padding='valid', name='conv10')(x)
    x = Activation('relu', name='relu_conv10')(x)
    x = GlobalAveragePooling2D()(x)
    out = Activation('softmax', name='loss')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = raw_img_input

    model = Model(inputs, out, name='squeezenet')

    # load weights
    if weights == 'imagenet':

        weights_path = get_file('squeezenet_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models')
        model.load_weights(weights_path)
        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first':

            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image data format convention '
                              '(`image_data_format="channels_first"`). '
                              'For best performance, set '
                              '`image_data_format="channels_last"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
    return model

# %%
X_train.shape[0:]
# Out:
# (4425, 224, 224, 3)

# %%
model = SqueezeNet(input_shape = (X_train.shape[1:]), weights = None, classes = Y_train.shape[1],
                  use_bn_on_input = True)
# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.Adam(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
loss_history = []
model.summary()
# Out:
# Model: "squeezenet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  batch_normalization (Batch  (None, 224, 224, 3)          12        ['input_1[0][0]']
#  Normalization)
#
#  conv1 (Conv2D)              (None, 111, 111, 64)         1792      ['batch_normalization[0][0]']
#
#  relu_conv1 (Activation)     (None, 111, 111, 64)         0         ['conv1[0][0]']
#
#  pool1 (MaxPooling2D)        (None, 55, 55, 64)           0         ['relu_conv1[0][0]']
#
#  fire2/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           1040      ['pool1[0][0]']
#
#  fire2/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire2/squeeze1x1[0][0]']
#  ivation)
#
#  fire2/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire2/expand1x1[0][0]']
#  vation)
#
#  fire2/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire2/expand3x3[0][0]']
#  vation)
#
#  fire2/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire2/relu_expand1x1[0][0]',
#                                                                      'fire2/relu_expand3x3[0][0]']
#
#  fire3/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           2064      ['fire2/concat[0][0]']
#
#  fire3/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire3/squeeze1x1[0][0]']
#  ivation)
#
#  fire3/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire3/expand1x1[0][0]']
#  vation)
#
#  fire3/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire3/expand3x3[0][0]']
#  vation)
#
#  fire3/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire3/relu_expand1x1[0][0]',
#                                                                      'fire3/relu_expand3x3[0][0]']
#
#  pool3 (MaxPooling2D)        (None, 27, 27, 128)          0         ['fire3/concat[0][0]']
#
#  fire4/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           4128      ['pool3[0][0]']
#
#  fire4/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire4/squeeze1x1[0][0]']
#  ivation)
#
#  fire4/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire4/expand1x1[0][0]']
#  vation)
#
#  fire4/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire4/expand3x3[0][0]']
#  vation)
#
#  fire4/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire4/relu_expand1x1[0][0]',
#                                                                      'fire4/relu_expand3x3[0][0]']
#
#  fire5/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           8224      ['fire4/concat[0][0]']
#
#  fire5/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire5/squeeze1x1[0][0]']
#  ivation)
#
#  fire5/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire5/expand1x1[0][0]']
#  vation)
#
#  fire5/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire5/expand3x3[0][0]']
#  vation)
#
#  fire5/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire5/relu_expand1x1[0][0]',
#                                                                      'fire5/relu_expand3x3[0][0]']
#
#  pool5 (MaxPooling2D)        (None, 13, 13, 256)          0         ['fire5/concat[0][0]']
#
#  drop9 (Dropout)             (None, 13, 13, 256)          0         ['pool5[0][0]']
#
#  conv10 (Conv2D)             (None, 13, 13, 4)            1028      ['drop9[0][0]']
#
#  relu_conv10 (Activation)    (None, 13, 13, 4)            0         ['conv10[0][0]']
#
#  global_average_pooling2d (  (None, 4)                    0         ['relu_conv10[0][0]']
#  GlobalAveragePooling2D)
#
#  loss (Activation)           (None, 4)                    0         ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 121456 (474.44 KB)
# Trainable params: 121450 (474.41 KB)
# Non-trainable params: 6 (24.00 Byte)
# __________________________________________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
EPOCHS = 150
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist=model.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/150
# 70/70 [==============================] - ETA: 0s - loss: 1.3568 - accuracy: 0.4646
# Epoch 1: val_accuracy improved from -inf to 0.23126, saving model to best_model.h5
# 70/70 [==============================] - 20s 127ms/step - loss: 1.3568 - accuracy: 0.4646 - val_loss: 1.4244 - val_accuracy: 0.2313
# Epoch 2/150
#  1/70 [..............................] - ETA: 5s - loss: 1.1865 - accuracy: 0.6094
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 69/70 [============================>.] - ETA: 0s - loss: 0.9820 - accuracy: 0.5686
# Epoch 2: val_accuracy improved from 0.23126 to 0.25474, saving model to best_model.h5
# 70/70 [==============================] - 7s 97ms/step - loss: 0.9822 - accuracy: 0.5688 - val_loss: 1.6887 - val_accuracy: 0.2547
# Epoch 3/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.6721 - accuracy: 0.7305
# Epoch 3: val_accuracy improved from 0.25474 to 0.51491, saving model to best_model.h5
# 70/70 [==============================] - 7s 97ms/step - loss: 0.6726 - accuracy: 0.7304 - val_loss: 1.1184 - val_accuracy: 0.5149
# Epoch 4/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.5688 - accuracy: 0.7894
# Epoch 4: val_accuracy improved from 0.51491 to 0.70461, saving model to best_model.h5
# 70/70 [==============================] - 7s 98ms/step - loss: 0.5683 - accuracy: 0.7896 - val_loss: 0.7637 - val_accuracy: 0.7046
# Epoch 5/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.4792 - accuracy: 0.8229
# Epoch 5: val_accuracy did not improve from 0.70461
# 70/70 [==============================] - 7s 97ms/step - loss: 0.4792 - accuracy: 0.8231 - val_loss: 0.7343 - val_accuracy: 0.6902
# Epoch 6/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.4092 - accuracy: 0.8481
# Epoch 6: val_accuracy improved from 0.70461 to 0.80036, saving model to best_model.h5
# 70/70 [==============================] - 7s 98ms/step - loss: 0.4089 - accuracy: 0.8484 - val_loss: 0.5095 - val_accuracy: 0.8004
# Epoch 7/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.3496 - accuracy: 0.8721
# Epoch 7: val_accuracy improved from 0.80036 to 0.89160, saving model to best_model.h5
# 70/70 [==============================] - 7s 98ms/step - loss: 0.3496 - accuracy: 0.8721 - val_loss: 0.3305 - val_accuracy: 0.8916
# Epoch 8/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.3411 - accuracy: 0.8764
# Epoch 8: val_accuracy did not improve from 0.89160
# 70/70 [==============================] - 7s 97ms/step - loss: 0.3408 - accuracy: 0.8764 - val_loss: 0.3379 - val_accuracy: 0.8835
# Epoch 9/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2965 - accuracy: 0.8856
# Epoch 9: val_accuracy improved from 0.89160 to 0.89792, saving model to best_model.h5
# 70/70 [==============================] - 7s 98ms/step - loss: 0.2969 - accuracy: 0.8856 - val_loss: 0.2765 - val_accuracy: 0.8979
# Epoch 10/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2699 - accuracy: 0.8990
# Epoch 10: val_accuracy did not improve from 0.89792
# 70/70 [==============================] - 7s 98ms/step - loss: 0.2694 - accuracy: 0.8992 - val_loss: 0.3609 - val_accuracy: 0.8437
# Epoch 11/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2791 - accuracy: 0.8897
# Epoch 11: val_accuracy improved from 0.89792 to 0.90786, saving model to best_model.h5
# 70/70 [==============================] - 7s 99ms/step - loss: 0.2786 - accuracy: 0.8899 - val_loss: 0.2404 - val_accuracy: 0.9079
# Epoch 12/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2517 - accuracy: 0.9035
# Epoch 12: val_accuracy improved from 0.90786 to 0.91238, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.2513 - accuracy: 0.9037 - val_loss: 0.2479 - val_accuracy: 0.9124
# Epoch 13/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2391 - accuracy: 0.9126
# Epoch 13: val_accuracy improved from 0.91238 to 0.91689, saving model to best_model.h5
# 70/70 [==============================] - 7s 99ms/step - loss: 0.2392 - accuracy: 0.9123 - val_loss: 0.2253 - val_accuracy: 0.9169
# Epoch 14/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2249 - accuracy: 0.9153
# Epoch 14: val_accuracy improved from 0.91689 to 0.92502, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.2249 - accuracy: 0.9153 - val_loss: 0.2092 - val_accuracy: 0.9250
# Epoch 15/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2185 - accuracy: 0.9180
# Epoch 15: val_accuracy improved from 0.92502 to 0.92593, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.2182 - accuracy: 0.9182 - val_loss: 0.2150 - val_accuracy: 0.9259
# Epoch 16/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2120 - accuracy: 0.9198
# Epoch 16: val_accuracy improved from 0.92593 to 0.92954, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.2118 - accuracy: 0.9200 - val_loss: 0.2020 - val_accuracy: 0.9295
# Epoch 17/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2260 - accuracy: 0.9099
# Epoch 17: val_accuracy improved from 0.92954 to 0.93044, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.2258 - accuracy: 0.9101 - val_loss: 0.1876 - val_accuracy: 0.9304
# Epoch 18/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2029 - accuracy: 0.9194
# Epoch 18: val_accuracy did not improve from 0.93044
# 70/70 [==============================] - 7s 100ms/step - loss: 0.2026 - accuracy: 0.9195 - val_loss: 0.2590 - val_accuracy: 0.9070
# Epoch 19/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2190 - accuracy: 0.9162
# Epoch 19: val_accuracy did not improve from 0.93044
# 70/70 [==============================] - 7s 100ms/step - loss: 0.2196 - accuracy: 0.9162 - val_loss: 0.2066 - val_accuracy: 0.9268
# Epoch 20/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2254 - accuracy: 0.9153
# Epoch 20: val_accuracy did not improve from 0.93044
# 70/70 [==============================] - 7s 100ms/step - loss: 0.2260 - accuracy: 0.9148 - val_loss: 0.1843 - val_accuracy: 0.9277
# Epoch 21/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1972 - accuracy: 0.9205
# Epoch 21: val_accuracy improved from 0.93044 to 0.94219, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.1973 - accuracy: 0.9205 - val_loss: 0.1640 - val_accuracy: 0.9422
# Epoch 22/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.2000 - accuracy: 0.9278
# Epoch 22: val_accuracy improved from 0.94219 to 0.94399, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.2000 - accuracy: 0.9279 - val_loss: 0.1572 - val_accuracy: 0.9440
# Epoch 23/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1954 - accuracy: 0.9228
# Epoch 23: val_accuracy improved from 0.94399 to 0.94490, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1954 - accuracy: 0.9227 - val_loss: 0.1548 - val_accuracy: 0.9449
# Epoch 24/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1794 - accuracy: 0.9287
# Epoch 24: val_accuracy did not improve from 0.94490
# 70/70 [==============================] - 7s 99ms/step - loss: 0.1795 - accuracy: 0.9286 - val_loss: 0.2200 - val_accuracy: 0.9097
# Epoch 25/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1747 - accuracy: 0.9318
# Epoch 25: val_accuracy did not improve from 0.94490
# 70/70 [==============================] - 7s 99ms/step - loss: 0.1747 - accuracy: 0.9318 - val_loss: 0.1727 - val_accuracy: 0.9350
# Epoch 26/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1844 - accuracy: 0.9241
# Epoch 26: val_accuracy improved from 0.94490 to 0.94761, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1856 - accuracy: 0.9238 - val_loss: 0.1384 - val_accuracy: 0.9476
# Epoch 27/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1575 - accuracy: 0.9429
# Epoch 27: val_accuracy did not improve from 0.94761
# 70/70 [==============================] - 7s 99ms/step - loss: 0.1572 - accuracy: 0.9431 - val_loss: 0.1507 - val_accuracy: 0.9431
# Epoch 28/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1541 - accuracy: 0.9420
# Epoch 28: val_accuracy did not improve from 0.94761
# 70/70 [==============================] - 7s 99ms/step - loss: 0.1542 - accuracy: 0.9417 - val_loss: 0.1432 - val_accuracy: 0.9476
# Epoch 29/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1494 - accuracy: 0.9418
# Epoch 29: val_accuracy improved from 0.94761 to 0.95303, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1492 - accuracy: 0.9419 - val_loss: 0.1254 - val_accuracy: 0.9530
# Epoch 30/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1390 - accuracy: 0.9475
# Epoch 30: val_accuracy did not improve from 0.95303
# 70/70 [==============================] - 7s 99ms/step - loss: 0.1388 - accuracy: 0.9476 - val_loss: 0.1298 - val_accuracy: 0.9512
# Epoch 31/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1549 - accuracy: 0.9427
# Epoch 31: val_accuracy did not improve from 0.95303
# 70/70 [==============================] - 7s 99ms/step - loss: 0.1553 - accuracy: 0.9426 - val_loss: 0.1991 - val_accuracy: 0.9196
# Epoch 32/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1724 - accuracy: 0.9373
# Epoch 32: val_accuracy improved from 0.95303 to 0.95483, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.1723 - accuracy: 0.9372 - val_loss: 0.1213 - val_accuracy: 0.9548
# Epoch 33/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1344 - accuracy: 0.9484
# Epoch 33: val_accuracy improved from 0.95483 to 0.96296, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1343 - accuracy: 0.9485 - val_loss: 0.1157 - val_accuracy: 0.9630
# Epoch 34/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1282 - accuracy: 0.9475
# Epoch 34: val_accuracy did not improve from 0.96296
# 70/70 [==============================] - 7s 99ms/step - loss: 0.1286 - accuracy: 0.9473 - val_loss: 0.1367 - val_accuracy: 0.9440
# Epoch 35/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1362 - accuracy: 0.9457
# Epoch 35: val_accuracy did not improve from 0.96296
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1360 - accuracy: 0.9458 - val_loss: 0.1295 - val_accuracy: 0.9512
# Epoch 36/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1320 - accuracy: 0.9506
# Epoch 36: val_accuracy did not improve from 0.96296
# 70/70 [==============================] - 7s 99ms/step - loss: 0.1320 - accuracy: 0.9507 - val_loss: 0.1301 - val_accuracy: 0.9548
# Epoch 37/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1335 - accuracy: 0.9490
# Epoch 37: val_accuracy did not improve from 0.96296
# 70/70 [==============================] - 7s 99ms/step - loss: 0.1333 - accuracy: 0.9492 - val_loss: 0.1152 - val_accuracy: 0.9557
# Epoch 38/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1242 - accuracy: 0.9558
# Epoch 38: val_accuracy improved from 0.96296 to 0.96748, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1239 - accuracy: 0.9559 - val_loss: 0.1059 - val_accuracy: 0.9675
# Epoch 39/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1271 - accuracy: 0.9509
# Epoch 39: val_accuracy did not improve from 0.96748
# 70/70 [==============================] - 7s 99ms/step - loss: 0.1269 - accuracy: 0.9510 - val_loss: 0.1589 - val_accuracy: 0.9386
# Epoch 40/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1297 - accuracy: 0.9518
# Epoch 40: val_accuracy did not improve from 0.96748
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1296 - accuracy: 0.9519 - val_loss: 0.1074 - val_accuracy: 0.9621
# Epoch 41/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1160 - accuracy: 0.9579
# Epoch 41: val_accuracy did not improve from 0.96748
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1163 - accuracy: 0.9577 - val_loss: 0.0947 - val_accuracy: 0.9675
# Epoch 42/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1191 - accuracy: 0.9556
# Epoch 42: val_accuracy improved from 0.96748 to 0.97200, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.1202 - accuracy: 0.9550 - val_loss: 0.0898 - val_accuracy: 0.9720
# Epoch 43/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1124 - accuracy: 0.9558
# Epoch 43: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 7s 99ms/step - loss: 0.1122 - accuracy: 0.9559 - val_loss: 0.0848 - val_accuracy: 0.9675
# Epoch 44/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1057 - accuracy: 0.9629
# Epoch 44: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1057 - accuracy: 0.9629 - val_loss: 0.0827 - val_accuracy: 0.9711
# Epoch 45/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1016 - accuracy: 0.9608
# Epoch 45: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1014 - accuracy: 0.9609 - val_loss: 0.0919 - val_accuracy: 0.9684
# Epoch 46/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0926 - accuracy: 0.9683
# Epoch 46: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0926 - accuracy: 0.9684 - val_loss: 0.1169 - val_accuracy: 0.9557
# Epoch 47/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.9581
# Epoch 47: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1082 - accuracy: 0.9580 - val_loss: 0.0879 - val_accuracy: 0.9711
# Epoch 48/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0935 - accuracy: 0.9660
# Epoch 48: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0937 - accuracy: 0.9659 - val_loss: 0.1032 - val_accuracy: 0.9593
# Epoch 49/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0917 - accuracy: 0.9678
# Epoch 49: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0920 - accuracy: 0.9677 - val_loss: 0.0851 - val_accuracy: 0.9720
# Epoch 50/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0857 - accuracy: 0.9699
# Epoch 50: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0858 - accuracy: 0.9699 - val_loss: 0.0890 - val_accuracy: 0.9693
# Epoch 51/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1024 - accuracy: 0.9613
# Epoch 51: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1038 - accuracy: 0.9609 - val_loss: 0.1402 - val_accuracy: 0.9422
# Epoch 52/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.1165 - accuracy: 0.9570
# Epoch 52: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 7s 100ms/step - loss: 0.1163 - accuracy: 0.9571 - val_loss: 0.1068 - val_accuracy: 0.9566
# Epoch 53/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0911 - accuracy: 0.9651
# Epoch 53: val_accuracy did not improve from 0.97200
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0914 - accuracy: 0.9650 - val_loss: 0.1340 - val_accuracy: 0.9413
# Epoch 54/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0928 - accuracy: 0.9669
# Epoch 54: val_accuracy improved from 0.97200 to 0.97290, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0929 - accuracy: 0.9668 - val_loss: 0.0684 - val_accuracy: 0.9729
# Epoch 55/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0908 - accuracy: 0.9656
# Epoch 55: val_accuracy did not improve from 0.97290
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0906 - accuracy: 0.9656 - val_loss: 0.1548 - val_accuracy: 0.9413
# Epoch 56/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0770 - accuracy: 0.9710
# Epoch 56: val_accuracy did not improve from 0.97290
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0772 - accuracy: 0.9711 - val_loss: 0.0916 - val_accuracy: 0.9621
# Epoch 57/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0769 - accuracy: 0.9726
# Epoch 57: val_accuracy improved from 0.97290 to 0.97471, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.0768 - accuracy: 0.9727 - val_loss: 0.0689 - val_accuracy: 0.9747
# Epoch 58/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0813 - accuracy: 0.9701
# Epoch 58: val_accuracy did not improve from 0.97471
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0814 - accuracy: 0.9702 - val_loss: 0.1218 - val_accuracy: 0.9648
# Epoch 59/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.9706
# Epoch 59: val_accuracy improved from 0.97471 to 0.97832, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.0823 - accuracy: 0.9706 - val_loss: 0.0609 - val_accuracy: 0.9783
# Epoch 60/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0869 - accuracy: 0.9683
# Epoch 60: val_accuracy improved from 0.97832 to 0.98103, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.0868 - accuracy: 0.9684 - val_loss: 0.0550 - val_accuracy: 0.9810
# Epoch 61/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0787 - accuracy: 0.9708
# Epoch 61: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0788 - accuracy: 0.9706 - val_loss: 0.0733 - val_accuracy: 0.9747
# Epoch 62/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0807 - accuracy: 0.9717
# Epoch 62: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0814 - accuracy: 0.9715 - val_loss: 0.0912 - val_accuracy: 0.9612
# Epoch 63/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0721 - accuracy: 0.9749
# Epoch 63: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0727 - accuracy: 0.9747 - val_loss: 0.0765 - val_accuracy: 0.9657
# Epoch 64/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0885 - accuracy: 0.9676
# Epoch 64: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0883 - accuracy: 0.9677 - val_loss: 0.0708 - val_accuracy: 0.9729
# Epoch 65/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9688
# Epoch 65: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0820 - accuracy: 0.9686 - val_loss: 0.0729 - val_accuracy: 0.9756
# Epoch 66/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9699
# Epoch 66: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0824 - accuracy: 0.9697 - val_loss: 0.0699 - val_accuracy: 0.9729
# Epoch 67/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9690
# Epoch 67: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0833 - accuracy: 0.9690 - val_loss: 0.0695 - val_accuracy: 0.9720
# Epoch 68/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0644 - accuracy: 0.9762
# Epoch 68: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0643 - accuracy: 0.9763 - val_loss: 0.0769 - val_accuracy: 0.9738
# Epoch 69/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0646 - accuracy: 0.9771
# Epoch 69: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0644 - accuracy: 0.9772 - val_loss: 0.0583 - val_accuracy: 0.9801
# Epoch 70/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0616 - accuracy: 0.9771
# Epoch 70: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0615 - accuracy: 0.9772 - val_loss: 0.0620 - val_accuracy: 0.9774
# Epoch 71/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0584 - accuracy: 0.9774
# Epoch 71: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0583 - accuracy: 0.9774 - val_loss: 0.0720 - val_accuracy: 0.9738
# Epoch 72/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0637 - accuracy: 0.9753
# Epoch 72: val_accuracy improved from 0.98103 to 0.98193, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.0635 - accuracy: 0.9754 - val_loss: 0.0616 - val_accuracy: 0.9819
# Epoch 73/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0560 - accuracy: 0.9783
# Epoch 73: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0561 - accuracy: 0.9783 - val_loss: 0.0691 - val_accuracy: 0.9801
# Epoch 74/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0584 - accuracy: 0.9783
# Epoch 74: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0589 - accuracy: 0.9781 - val_loss: 0.0572 - val_accuracy: 0.9792
# Epoch 75/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9774
# Epoch 75: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0617 - accuracy: 0.9772 - val_loss: 0.1073 - val_accuracy: 0.9675
# Epoch 76/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0629 - accuracy: 0.9789
# Epoch 76: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0627 - accuracy: 0.9790 - val_loss: 0.0744 - val_accuracy: 0.9729
# Epoch 77/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0603 - accuracy: 0.9762
# Epoch 77: val_accuracy did not improve from 0.98193
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0603 - accuracy: 0.9763 - val_loss: 0.1080 - val_accuracy: 0.9557
# Epoch 78/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.9774
# Epoch 78: val_accuracy improved from 0.98193 to 0.98645, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0624 - accuracy: 0.9774 - val_loss: 0.0408 - val_accuracy: 0.9864
# Epoch 79/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0630 - accuracy: 0.9764
# Epoch 79: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0629 - accuracy: 0.9765 - val_loss: 0.0686 - val_accuracy: 0.9675
# Epoch 80/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0541 - accuracy: 0.9796
# Epoch 80: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0540 - accuracy: 0.9797 - val_loss: 0.0490 - val_accuracy: 0.9819
# Epoch 81/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0500 - accuracy: 0.9817
# Epoch 81: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0502 - accuracy: 0.9815 - val_loss: 0.0669 - val_accuracy: 0.9765
# Epoch 82/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0542 - accuracy: 0.9810
# Epoch 82: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0542 - accuracy: 0.9810 - val_loss: 0.0680 - val_accuracy: 0.9792
# Epoch 83/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0463 - accuracy: 0.9812
# Epoch 83: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0463 - accuracy: 0.9812 - val_loss: 0.0614 - val_accuracy: 0.9783
# Epoch 84/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9798
# Epoch 84: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0505 - accuracy: 0.9797 - val_loss: 0.0589 - val_accuracy: 0.9666
# Epoch 85/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0555 - accuracy: 0.9787
# Epoch 85: val_accuracy did not improve from 0.98645
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0554 - accuracy: 0.9788 - val_loss: 0.0361 - val_accuracy: 0.9855
# Epoch 86/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0404 - accuracy: 0.9860
# Epoch 86: val_accuracy improved from 0.98645 to 0.98826, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0408 - accuracy: 0.9858 - val_loss: 0.0483 - val_accuracy: 0.9883
# Epoch 87/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0612 - accuracy: 0.9785
# Epoch 87: val_accuracy improved from 0.98826 to 0.99006, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.0612 - accuracy: 0.9785 - val_loss: 0.0344 - val_accuracy: 0.9901
# Epoch 88/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0461 - accuracy: 0.9846
# Epoch 88: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0461 - accuracy: 0.9846 - val_loss: 0.0386 - val_accuracy: 0.9874
# Epoch 89/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0429 - accuracy: 0.9839
# Epoch 89: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0428 - accuracy: 0.9840 - val_loss: 0.0528 - val_accuracy: 0.9729
# Epoch 90/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0508 - accuracy: 0.9803
# Epoch 90: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0507 - accuracy: 0.9803 - val_loss: 0.0395 - val_accuracy: 0.9892
# Epoch 91/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9857
# Epoch 91: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0394 - accuracy: 0.9858 - val_loss: 0.1111 - val_accuracy: 0.9539
# Epoch 92/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0831 - accuracy: 0.9694
# Epoch 92: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0830 - accuracy: 0.9695 - val_loss: 0.0389 - val_accuracy: 0.9837
# Epoch 93/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0542 - accuracy: 0.9814
# Epoch 93: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0541 - accuracy: 0.9815 - val_loss: 0.0418 - val_accuracy: 0.9837
# Epoch 94/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.9785
# Epoch 94: val_accuracy did not improve from 0.99006
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0624 - accuracy: 0.9785 - val_loss: 0.0702 - val_accuracy: 0.9783
# Epoch 95/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0468 - accuracy: 0.9826
# Epoch 95: val_accuracy improved from 0.99006 to 0.99097, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0468 - accuracy: 0.9826 - val_loss: 0.0342 - val_accuracy: 0.9910
# Epoch 96/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0479 - accuracy: 0.9817
# Epoch 96: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0480 - accuracy: 0.9815 - val_loss: 0.0869 - val_accuracy: 0.9702
# Epoch 97/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0659 - accuracy: 0.9796
# Epoch 97: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0658 - accuracy: 0.9797 - val_loss: 0.0334 - val_accuracy: 0.9910
# Epoch 98/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0339 - accuracy: 0.9896
# Epoch 98: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0338 - accuracy: 0.9896 - val_loss: 0.0372 - val_accuracy: 0.9864
# Epoch 99/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0588 - accuracy: 0.9798
# Epoch 99: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0599 - accuracy: 0.9797 - val_loss: 0.0549 - val_accuracy: 0.9828
# Epoch 100/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0660 - accuracy: 0.9753
# Epoch 100: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0659 - accuracy: 0.9754 - val_loss: 0.0388 - val_accuracy: 0.9855
# Epoch 101/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0342 - accuracy: 0.9878
# Epoch 101: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0341 - accuracy: 0.9878 - val_loss: 0.0344 - val_accuracy: 0.9883
# Epoch 102/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9889
# Epoch 102: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0348 - accuracy: 0.9889 - val_loss: 0.0323 - val_accuracy: 0.9883
# Epoch 103/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9866
# Epoch 103: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0364 - accuracy: 0.9867 - val_loss: 0.0377 - val_accuracy: 0.9846
# Epoch 104/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0362 - accuracy: 0.9885
# Epoch 104: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0361 - accuracy: 0.9885 - val_loss: 0.0425 - val_accuracy: 0.9892
# Epoch 105/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9855
# Epoch 105: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0391 - accuracy: 0.9855 - val_loss: 0.0315 - val_accuracy: 0.9874
# Epoch 106/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0337 - accuracy: 0.9896
# Epoch 106: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0337 - accuracy: 0.9896 - val_loss: 0.0321 - val_accuracy: 0.9883
# Epoch 107/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9896
# Epoch 107: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0283 - accuracy: 0.9896 - val_loss: 0.0884 - val_accuracy: 0.9584
# Epoch 108/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0385 - accuracy: 0.9848
# Epoch 108: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0384 - accuracy: 0.9849 - val_loss: 0.0326 - val_accuracy: 0.9874
# Epoch 109/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0431 - accuracy: 0.9837
# Epoch 109: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0433 - accuracy: 0.9835 - val_loss: 0.1008 - val_accuracy: 0.9603
# Epoch 110/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0741 - accuracy: 0.9753
# Epoch 110: val_accuracy improved from 0.99097 to 0.99187, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.0740 - accuracy: 0.9754 - val_loss: 0.0272 - val_accuracy: 0.9919
# Epoch 111/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0407 - accuracy: 0.9853
# Epoch 111: val_accuracy improved from 0.99187 to 0.99277, saving model to best_model.h5
# 70/70 [==============================] - 7s 101ms/step - loss: 0.0408 - accuracy: 0.9853 - val_loss: 0.0294 - val_accuracy: 0.9928
# Epoch 112/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0386 - accuracy: 0.9878
# Epoch 112: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0385 - accuracy: 0.9878 - val_loss: 0.0280 - val_accuracy: 0.9874
# Epoch 113/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9894
# Epoch 113: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0331 - accuracy: 0.9894 - val_loss: 0.0352 - val_accuracy: 0.9828
# Epoch 114/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9887
# Epoch 114: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0324 - accuracy: 0.9887 - val_loss: 0.0363 - val_accuracy: 0.9864
# Epoch 115/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9873
# Epoch 115: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0332 - accuracy: 0.9873 - val_loss: 0.0307 - val_accuracy: 0.9892
# Epoch 116/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9898
# Epoch 116: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0314 - accuracy: 0.9898 - val_loss: 0.0372 - val_accuracy: 0.9828
# Epoch 117/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0464 - accuracy: 0.9855
# Epoch 117: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0463 - accuracy: 0.9855 - val_loss: 0.0442 - val_accuracy: 0.9810
# Epoch 118/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0357 - accuracy: 0.9869
# Epoch 118: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0356 - accuracy: 0.9869 - val_loss: 0.0390 - val_accuracy: 0.9846
# Epoch 119/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9857
# Epoch 119: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0378 - accuracy: 0.9858 - val_loss: 0.0246 - val_accuracy: 0.9892
# Epoch 120/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9900
# Epoch 120: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0289 - accuracy: 0.9901 - val_loss: 0.0396 - val_accuracy: 0.9874
# Epoch 121/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0263 - accuracy: 0.9907
# Epoch 121: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0263 - accuracy: 0.9907 - val_loss: 0.0477 - val_accuracy: 0.9801
# Epoch 122/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9894
# Epoch 122: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0323 - accuracy: 0.9892 - val_loss: 0.0460 - val_accuracy: 0.9819
# Epoch 123/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0564 - accuracy: 0.9792
# Epoch 123: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0565 - accuracy: 0.9790 - val_loss: 0.0232 - val_accuracy: 0.9928
# Epoch 124/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0308 - accuracy: 0.9887
# Epoch 124: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0307 - accuracy: 0.9887 - val_loss: 0.0257 - val_accuracy: 0.9910
# Epoch 125/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 0.9930
# Epoch 125: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0247 - accuracy: 0.9930 - val_loss: 0.0515 - val_accuracy: 0.9828
# Epoch 126/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0243 - accuracy: 0.9921
# Epoch 126: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0243 - accuracy: 0.9921 - val_loss: 0.0231 - val_accuracy: 0.9910
# Epoch 127/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0680 - accuracy: 0.9776
# Epoch 127: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0682 - accuracy: 0.9774 - val_loss: 0.0582 - val_accuracy: 0.9810
# Epoch 128/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0471 - accuracy: 0.9826
# Epoch 128: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0470 - accuracy: 0.9826 - val_loss: 0.0244 - val_accuracy: 0.9919
# Epoch 129/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9907
# Epoch 129: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0284 - accuracy: 0.9907 - val_loss: 0.0507 - val_accuracy: 0.9729
# Epoch 130/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0275 - accuracy: 0.9914
# Epoch 130: val_accuracy did not improve from 0.99277
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0275 - accuracy: 0.9914 - val_loss: 0.0258 - val_accuracy: 0.9910
# Epoch 131/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0285 - accuracy: 0.9907
# Epoch 131: val_accuracy improved from 0.99277 to 0.99548, saving model to best_model.h5
# 70/70 [==============================] - 7s 100ms/step - loss: 0.0285 - accuracy: 0.9907 - val_loss: 0.0211 - val_accuracy: 0.9955
# Epoch 132/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 0.9882
# Epoch 132: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0319 - accuracy: 0.9880 - val_loss: 0.0445 - val_accuracy: 0.9846
# Epoch 133/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0622 - accuracy: 0.9787
# Epoch 133: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0621 - accuracy: 0.9788 - val_loss: 0.0230 - val_accuracy: 0.9928
# Epoch 134/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 0.9914
# Epoch 134: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0261 - accuracy: 0.9914 - val_loss: 0.0247 - val_accuracy: 0.9937
# Epoch 135/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0258 - accuracy: 0.9934
# Epoch 135: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0257 - accuracy: 0.9934 - val_loss: 0.0301 - val_accuracy: 0.9864
# Epoch 136/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 0.9928
# Epoch 136: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0235 - accuracy: 0.9923 - val_loss: 0.0528 - val_accuracy: 0.9892
# Epoch 137/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0577 - accuracy: 0.9814
# Epoch 137: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0577 - accuracy: 0.9815 - val_loss: 0.0282 - val_accuracy: 0.9919
# Epoch 138/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0359 - accuracy: 0.9882
# Epoch 138: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0359 - accuracy: 0.9882 - val_loss: 0.0318 - val_accuracy: 0.9874
# Epoch 139/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9903
# Epoch 139: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0283 - accuracy: 0.9903 - val_loss: 0.0451 - val_accuracy: 0.9783
# Epoch 140/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 0.9928
# Epoch 140: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0262 - accuracy: 0.9928 - val_loss: 0.0244 - val_accuracy: 0.9901
# Epoch 141/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0264 - accuracy: 0.9909
# Epoch 141: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 0.1390 - val_accuracy: 0.9666
# Epoch 142/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0506 - accuracy: 0.9823
# Epoch 142: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0509 - accuracy: 0.9821 - val_loss: 0.0392 - val_accuracy: 0.9855
# Epoch 143/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 0.9918
# Epoch 143: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0247 - accuracy: 0.9919 - val_loss: 0.0465 - val_accuracy: 0.9801
# Epoch 144/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0210 - accuracy: 0.9925
# Epoch 144: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0211 - accuracy: 0.9925 - val_loss: 0.0222 - val_accuracy: 0.9910
# Epoch 145/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9930
# Epoch 145: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0226 - accuracy: 0.9930 - val_loss: 0.0279 - val_accuracy: 0.9892
# Epoch 146/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0259 - accuracy: 0.9921
# Epoch 146: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0263 - accuracy: 0.9919 - val_loss: 0.0345 - val_accuracy: 0.9864
# Epoch 147/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9851
# Epoch 147: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0422 - accuracy: 0.9851 - val_loss: 0.0536 - val_accuracy: 0.9747
# Epoch 148/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0285 - accuracy: 0.9882
# Epoch 148: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0285 - accuracy: 0.9882 - val_loss: 0.0214 - val_accuracy: 0.9928
# Epoch 149/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0397 - accuracy: 0.9871
# Epoch 149: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0396 - accuracy: 0.9871 - val_loss: 0.0259 - val_accuracy: 0.9901
# Epoch 150/150
# 69/70 [============================>.] - ETA: 0s - loss: 0.0294 - accuracy: 0.9905
# Epoch 150: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 7s 99ms/step - loss: 0.0295 - accuracy: 0.9905 - val_loss: 0.0349 - val_accuracy: 0.9855

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 35/35 [==============================] - 1s 15ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("SquezeNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# SquezeNet MODEL SONUÇLARI
# Doğruluk:  0.995483288166215
# F1_Skor:  0.9955984687630767
# Hassasiyet:  0.9955954373566425
# Duyarlılık:  0.9956045727322322

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# [[283   3   0   0]
#  [  2 280   0   0]
#  [  0   0 283   0]
#  [  0   0   0 256]]
# <Axes: >
