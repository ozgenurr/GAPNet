# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 4062 images belonging to 4 classes.
# (4062, 224, 224, 3)
# (4062, 4)

# %%
#Converting  our color images to a vector
x=x.reshape(4062,224*224*3)

# %%
x.shape
# Out:
# (4062, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (5532, 150528)

# %%
X_smote=X_smote.reshape(5532,224,224,3)

# %% [markdown]
# # 1. sınıf: 1179  2. sınıf: 1076 3. sınıf: 1142 4. sınıf: 1180

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (4062, 150528)
# Shape of X after SMOTE: (5532, 224, 224, 3)

# %%
"""
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
data_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
"""
# Out:
# "\ndisease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']\ndata_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'\ntrain_dir = os.path.join(data_dir)\n\ntrain_data = []\nfor defects_id, sp in enumerate(disease_types):\n    for file in os.listdir(os.path.join(train_dir, sp)):\n        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])\n\ntrain = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])\n\nSEED = 42\ntrain = train.sample(frac=1, random_state=SEED)\ntrain.index = np.arange(len(train)) # Reset indices\n"

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (5532, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
pip install keras_applications
# Out:
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_applications) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras_applications) (3.9.0)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8

# %%
from keras_applications.imagenet_utils import _obtain_input_shape
from keras import backend as K
from keras.layers import Input, Convolution2D, MaxPooling2D, Activation, concatenate, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.models import Model
#from keras.engine.topology import get_source_inputs
from keras.utils import get_file
#from keras.utils import layer_utils

sq1x1 = "squeeze1x1"
exp1x1 = "expand1x1"
exp3x3 = "expand3x3"
relu = "relu_"

WEIGHTS_PATH = "https://github.com/rcmalli/keras-squeezenet/releases/download/v1.0/squeezenet_weights_tf_dim_ordering_tf_kernels.h5"

# Modular function for Fire Node

def fire_module(x, fire_id, squeeze=16, expand=64):
    s_id = 'fire' + str(fire_id) + '/'

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3

    x = Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = Activation('relu', name=s_id + relu + sq1x1)(x)

    left = Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
    left = Activation('relu', name=s_id + relu + exp1x1)(left)

    right = Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
    right = Activation('relu', name=s_id + relu + exp3x3)(right)

    x = concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x


# Original SqueezeNet from paper.

def SqueezeNet(input_tensor=None, input_shape=None,
               weights='imagenet',
               classes=1000,
              use_bn_on_input = False, # to avoid preprocessing
               first_stride = 2
              ):
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')


    input_shape = _obtain_input_shape(input_shape,
                                      default_size=224,
                                      min_size=48,
                                      data_format=K.image_data_format(),
                                     require_flatten = False)

    if input_tensor is None:
        raw_img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
    if use_bn_on_input:
        img_input = BatchNormalization()(raw_img_input)
    else:
        img_input = raw_img_input


    x = Convolution2D(64, (3, 3), strides=(first_stride, first_stride), padding='valid', name='conv1')(img_input)
    x = Activation('relu', name='relu_conv1')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5')(x)

    x = fire_module(x, fire_id=6, squeeze=48, expand=192)
    x = fire_module(x, fire_id=7, squeeze=48, expand=192)
    x = fire_module(x, fire_id=8, squeeze=64, expand=256)
    x = fire_module(x, fire_id=9, squeeze=64, expand=256)
    x = Dropout(0.5, name='drop9')(x)

    x = Convolution2D(classes, (1, 1), padding='valid', name='conv10')(x)
    x = Activation('relu', name='relu_conv10')(x)
    x = GlobalAveragePooling2D()(x)
    out = Activation('softmax', name='loss')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = raw_img_input

    model = Model(inputs, out, name='squeezenet')

    # load weights
    if weights == 'imagenet':

        weights_path = get_file('squeezenet_weights_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH,
                                    cache_subdir='models')
        model.load_weights(weights_path)
        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first':

            if K.backend() == 'tensorflow':
                warnings.warn('You are using the TensorFlow backend, yet you '
                              'are using the Theano '
                              'image data format convention '
                              '(`image_data_format="channels_first"`). '
                              'For best performance, set '
                              '`image_data_format="channels_last"` in '
                              'your Keras config '
                              'at ~/.keras/keras.json.')
    return model

# %%
X_train.shape[0:]
# Out:
# (4425, 224, 224, 3)

# %%
model = SqueezeNet(input_shape = (X_train.shape[1:]), weights = None, classes = Y_train.shape[1],
                  use_bn_on_input = True)
# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.Adam(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
loss_history = []
model.summary()
# Out:
# Model: "squeezenet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  batch_normalization (Batch  (None, 224, 224, 3)          12        ['input_1[0][0]']
#  Normalization)
#
#  conv1 (Conv2D)              (None, 111, 111, 64)         1792      ['batch_normalization[0][0]']
#
#  relu_conv1 (Activation)     (None, 111, 111, 64)         0         ['conv1[0][0]']
#
#  pool1 (MaxPooling2D)        (None, 55, 55, 64)           0         ['relu_conv1[0][0]']
#
#  fire2/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           1040      ['pool1[0][0]']
#
#  fire2/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire2/squeeze1x1[0][0]']
#  ivation)
#
#  fire2/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire2/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire2/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire2/expand1x1[0][0]']
#  vation)
#
#  fire2/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire2/expand3x3[0][0]']
#  vation)
#
#  fire2/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire2/relu_expand1x1[0][0]',
#                                                                      'fire2/relu_expand3x3[0][0]']
#
#  fire3/squeeze1x1 (Conv2D)   (None, 55, 55, 16)           2064      ['fire2/concat[0][0]']
#
#  fire3/relu_squeeze1x1 (Act  (None, 55, 55, 16)           0         ['fire3/squeeze1x1[0][0]']
#  ivation)
#
#  fire3/expand1x1 (Conv2D)    (None, 55, 55, 64)           1088      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/expand3x3 (Conv2D)    (None, 55, 55, 64)           9280      ['fire3/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire3/relu_expand1x1 (Acti  (None, 55, 55, 64)           0         ['fire3/expand1x1[0][0]']
#  vation)
#
#  fire3/relu_expand3x3 (Acti  (None, 55, 55, 64)           0         ['fire3/expand3x3[0][0]']
#  vation)
#
#  fire3/concat (Concatenate)  (None, 55, 55, 128)          0         ['fire3/relu_expand1x1[0][0]',
#                                                                      'fire3/relu_expand3x3[0][0]']
#
#  pool3 (MaxPooling2D)        (None, 27, 27, 128)          0         ['fire3/concat[0][0]']
#
#  fire4/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           4128      ['pool3[0][0]']
#
#  fire4/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire4/squeeze1x1[0][0]']
#  ivation)
#
#  fire4/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire4/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire4/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire4/expand1x1[0][0]']
#  vation)
#
#  fire4/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire4/expand3x3[0][0]']
#  vation)
#
#  fire4/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire4/relu_expand1x1[0][0]',
#                                                                      'fire4/relu_expand3x3[0][0]']
#
#  fire5/squeeze1x1 (Conv2D)   (None, 27, 27, 32)           8224      ['fire4/concat[0][0]']
#
#  fire5/relu_squeeze1x1 (Act  (None, 27, 27, 32)           0         ['fire5/squeeze1x1[0][0]']
#  ivation)
#
#  fire5/expand1x1 (Conv2D)    (None, 27, 27, 128)          4224      ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/expand3x3 (Conv2D)    (None, 27, 27, 128)          36992     ['fire5/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire5/relu_expand1x1 (Acti  (None, 27, 27, 128)          0         ['fire5/expand1x1[0][0]']
#  vation)
#
#  fire5/relu_expand3x3 (Acti  (None, 27, 27, 128)          0         ['fire5/expand3x3[0][0]']
#  vation)
#
#  fire5/concat (Concatenate)  (None, 27, 27, 256)          0         ['fire5/relu_expand1x1[0][0]',
#                                                                      'fire5/relu_expand3x3[0][0]']
#
#  pool5 (MaxPooling2D)        (None, 13, 13, 256)          0         ['fire5/concat[0][0]']
#
#  fire6/squeeze1x1 (Conv2D)   (None, 13, 13, 48)           12336     ['pool5[0][0]']
#
#  fire6/relu_squeeze1x1 (Act  (None, 13, 13, 48)           0         ['fire6/squeeze1x1[0][0]']
#  ivation)
#
#  fire6/expand1x1 (Conv2D)    (None, 13, 13, 192)          9408      ['fire6/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire6/expand3x3 (Conv2D)    (None, 13, 13, 192)          83136     ['fire6/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire6/relu_expand1x1 (Acti  (None, 13, 13, 192)          0         ['fire6/expand1x1[0][0]']
#  vation)
#
#  fire6/relu_expand3x3 (Acti  (None, 13, 13, 192)          0         ['fire6/expand3x3[0][0]']
#  vation)
#
#  fire6/concat (Concatenate)  (None, 13, 13, 384)          0         ['fire6/relu_expand1x1[0][0]',
#                                                                      'fire6/relu_expand3x3[0][0]']
#
#  fire7/squeeze1x1 (Conv2D)   (None, 13, 13, 48)           18480     ['fire6/concat[0][0]']
#
#  fire7/relu_squeeze1x1 (Act  (None, 13, 13, 48)           0         ['fire7/squeeze1x1[0][0]']
#  ivation)
#
#  fire7/expand1x1 (Conv2D)    (None, 13, 13, 192)          9408      ['fire7/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire7/expand3x3 (Conv2D)    (None, 13, 13, 192)          83136     ['fire7/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire7/relu_expand1x1 (Acti  (None, 13, 13, 192)          0         ['fire7/expand1x1[0][0]']
#  vation)
#
#  fire7/relu_expand3x3 (Acti  (None, 13, 13, 192)          0         ['fire7/expand3x3[0][0]']
#  vation)
#
#  fire7/concat (Concatenate)  (None, 13, 13, 384)          0         ['fire7/relu_expand1x1[0][0]',
#                                                                      'fire7/relu_expand3x3[0][0]']
#
#  fire8/squeeze1x1 (Conv2D)   (None, 13, 13, 64)           24640     ['fire7/concat[0][0]']
#
#  fire8/relu_squeeze1x1 (Act  (None, 13, 13, 64)           0         ['fire8/squeeze1x1[0][0]']
#  ivation)
#
#  fire8/expand1x1 (Conv2D)    (None, 13, 13, 256)          16640     ['fire8/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire8/expand3x3 (Conv2D)    (None, 13, 13, 256)          147712    ['fire8/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire8/relu_expand1x1 (Acti  (None, 13, 13, 256)          0         ['fire8/expand1x1[0][0]']
#  vation)
#
#  fire8/relu_expand3x3 (Acti  (None, 13, 13, 256)          0         ['fire8/expand3x3[0][0]']
#  vation)
#
#  fire8/concat (Concatenate)  (None, 13, 13, 512)          0         ['fire8/relu_expand1x1[0][0]',
#                                                                      'fire8/relu_expand3x3[0][0]']
#
#  fire9/squeeze1x1 (Conv2D)   (None, 13, 13, 64)           32832     ['fire8/concat[0][0]']
#
#  fire9/relu_squeeze1x1 (Act  (None, 13, 13, 64)           0         ['fire9/squeeze1x1[0][0]']
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
#  ivation)
#
#  fire9/expand1x1 (Conv2D)    (None, 13, 13, 256)          16640     ['fire9/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire9/expand3x3 (Conv2D)    (None, 13, 13, 256)          147712    ['fire9/relu_squeeze1x1[0][0]'
#                                                                     ]
#
#  fire9/relu_expand1x1 (Acti  (None, 13, 13, 256)          0         ['fire9/expand1x1[0][0]']
#  vation)
#
#  fire9/relu_expand3x3 (Acti  (None, 13, 13, 256)          0         ['fire9/expand3x3[0][0]']
#  vation)
#
#  fire9/concat (Concatenate)  (None, 13, 13, 512)          0         ['fire9/relu_expand1x1[0][0]',
#                                                                      'fire9/relu_expand3x3[0][0]']
#
#  drop9 (Dropout)             (None, 13, 13, 512)          0         ['fire9/concat[0][0]']
#
#  conv10 (Conv2D)             (None, 13, 13, 4)            2052      ['drop9[0][0]']
#
#  relu_conv10 (Activation)    (None, 13, 13, 4)            0         ['conv10[0][0]']
#
#  global_average_pooling2d (  (None, 4)                    0         ['relu_conv10[0][0]']
#  GlobalAveragePooling2D)
#
#  loss (Activation)           (None, 4)                    0         ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 724560 (2.76 MB)
# Trainable params: 724554 (2.76 MB)
# Non-trainable params: 6 (24.00 Byte)
# __________________________________________________________________________________________________

# %%
EPOCHS = 100
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist=model.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/100
# 70/70 [==============================] - ETA: 0s - loss: 1.3040 - accuracy: 0.3677
# Epoch 1: val_accuracy improved from -inf to 0.25565, saving model to best_model.h5
# 70/70 [==============================] - 23s 148ms/step - loss: 1.3040 - accuracy: 0.3677 - val_loss: 1.4598 - val_accuracy: 0.2556
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 69/70 [============================>.] - ETA: 0s - loss: 0.9256 - accuracy: 0.5466
# Epoch 2: val_accuracy improved from 0.25565 to 0.25655, saving model to best_model.h5
# 70/70 [==============================] - 8s 114ms/step - loss: 0.9255 - accuracy: 0.5464 - val_loss: 2.0685 - val_accuracy: 0.2565
# Epoch 3/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.7740 - accuracy: 0.6590
# Epoch 3: val_accuracy improved from 0.25655 to 0.26287, saving model to best_model.h5
# 70/70 [==============================] - 8s 114ms/step - loss: 0.7733 - accuracy: 0.6597 - val_loss: 2.2427 - val_accuracy: 0.2629
# Epoch 4/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.6554 - accuracy: 0.7563
# Epoch 4: val_accuracy improved from 0.26287 to 0.28004, saving model to best_model.h5
# 70/70 [==============================] - 8s 115ms/step - loss: 0.6551 - accuracy: 0.7564 - val_loss: 2.0364 - val_accuracy: 0.2800
# Epoch 5/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.5605 - accuracy: 0.7930
# Epoch 5: val_accuracy improved from 0.28004 to 0.69828, saving model to best_model.h5
# 70/70 [==============================] - 8s 115ms/step - loss: 0.5605 - accuracy: 0.7930 - val_loss: 0.7017 - val_accuracy: 0.6983
# Epoch 6/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.4908 - accuracy: 0.8130
# Epoch 6: val_accuracy improved from 0.69828 to 0.80668, saving model to best_model.h5
# 70/70 [==============================] - 8s 115ms/step - loss: 0.4915 - accuracy: 0.8127 - val_loss: 0.4741 - val_accuracy: 0.8067
# Epoch 7/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.3919 - accuracy: 0.8510
# Epoch 7: val_accuracy improved from 0.80668 to 0.85456, saving model to best_model.h5
# 70/70 [==============================] - 8s 116ms/step - loss: 0.3919 - accuracy: 0.8511 - val_loss: 0.3833 - val_accuracy: 0.8546
# Epoch 8/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.3434 - accuracy: 0.8680
# Epoch 8: val_accuracy improved from 0.85456 to 0.86540, saving model to best_model.h5
# 70/70 [==============================] - 8s 116ms/step - loss: 0.3443 - accuracy: 0.8678 - val_loss: 0.3594 - val_accuracy: 0.8654
# Epoch 9/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.3505 - accuracy: 0.8675
# Epoch 9: val_accuracy improved from 0.86540 to 0.86811, saving model to best_model.h5
# 70/70 [==============================] - 8s 116ms/step - loss: 0.3501 - accuracy: 0.8676 - val_loss: 0.3284 - val_accuracy: 0.8681
# Epoch 10/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.3062 - accuracy: 0.8841
# Epoch 10: val_accuracy improved from 0.86811 to 0.89341, saving model to best_model.h5
# 70/70 [==============================] - 8s 117ms/step - loss: 0.3063 - accuracy: 0.8841 - val_loss: 0.2958 - val_accuracy: 0.8934
# Epoch 11/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.2701 - accuracy: 0.8981
# Epoch 11: val_accuracy improved from 0.89341 to 0.90605, saving model to best_model.h5
# 70/70 [==============================] - 8s 118ms/step - loss: 0.2696 - accuracy: 0.8983 - val_loss: 0.2627 - val_accuracy: 0.9061
# Epoch 12/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.2525 - accuracy: 0.9033
# Epoch 12: val_accuracy did not improve from 0.90605
# 70/70 [==============================] - 8s 116ms/step - loss: 0.2524 - accuracy: 0.9035 - val_loss: 0.3026 - val_accuracy: 0.8826
# Epoch 13/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.2487 - accuracy: 0.9085
# Epoch 13: val_accuracy improved from 0.90605 to 0.91509, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.2494 - accuracy: 0.9082 - val_loss: 0.2117 - val_accuracy: 0.9151
# Epoch 14/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.2511 - accuracy: 0.9004
# Epoch 14: val_accuracy did not improve from 0.91509
# 70/70 [==============================] - 8s 117ms/step - loss: 0.2508 - accuracy: 0.9006 - val_loss: 0.2795 - val_accuracy: 0.8979
# Epoch 15/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.2138 - accuracy: 0.9230
# Epoch 15: val_accuracy improved from 0.91509 to 0.92141, saving model to best_model.h5
# 70/70 [==============================] - 8s 120ms/step - loss: 0.2136 - accuracy: 0.9229 - val_loss: 0.1988 - val_accuracy: 0.9214
# Epoch 16/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.2237 - accuracy: 0.9169
# Epoch 16: val_accuracy did not improve from 0.92141
# 70/70 [==============================] - 8s 118ms/step - loss: 0.2242 - accuracy: 0.9168 - val_loss: 0.2499 - val_accuracy: 0.8970
# Epoch 17/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1889 - accuracy: 0.9284
# Epoch 17: val_accuracy improved from 0.92141 to 0.92864, saving model to best_model.h5
# 70/70 [==============================] - 8s 120ms/step - loss: 0.1887 - accuracy: 0.9286 - val_loss: 0.1775 - val_accuracy: 0.9286
# Epoch 18/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1753 - accuracy: 0.9303
# Epoch 18: val_accuracy did not improve from 0.92864
# 70/70 [==============================] - 8s 118ms/step - loss: 0.1750 - accuracy: 0.9304 - val_loss: 0.2311 - val_accuracy: 0.8997
# Epoch 19/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1792 - accuracy: 0.9327
# Epoch 19: val_accuracy improved from 0.92864 to 0.95122, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.1791 - accuracy: 0.9329 - val_loss: 0.1393 - val_accuracy: 0.9512
# Epoch 20/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1321 - accuracy: 0.9493
# Epoch 20: val_accuracy improved from 0.95122 to 0.96567, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.1319 - accuracy: 0.9494 - val_loss: 0.1128 - val_accuracy: 0.9657
# Epoch 21/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1819 - accuracy: 0.9334
# Epoch 21: val_accuracy did not improve from 0.96567
# 70/70 [==============================] - 8s 116ms/step - loss: 0.1830 - accuracy: 0.9331 - val_loss: 0.1323 - val_accuracy: 0.9566
# Epoch 22/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1551 - accuracy: 0.9402
# Epoch 22: val_accuracy did not improve from 0.96567
# 70/70 [==============================] - 8s 117ms/step - loss: 0.1551 - accuracy: 0.9403 - val_loss: 0.1370 - val_accuracy: 0.9449
# Epoch 23/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1349 - accuracy: 0.9524
# Epoch 23: val_accuracy did not improve from 0.96567
# 70/70 [==============================] - 8s 117ms/step - loss: 0.1348 - accuracy: 0.9525 - val_loss: 0.1060 - val_accuracy: 0.9612
# Epoch 24/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1015 - accuracy: 0.9647
# Epoch 24: val_accuracy did not improve from 0.96567
# 70/70 [==============================] - 8s 117ms/step - loss: 0.1013 - accuracy: 0.9647 - val_loss: 0.1768 - val_accuracy: 0.9295
# Epoch 25/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1033 - accuracy: 0.9649
# Epoch 25: val_accuracy improved from 0.96567 to 0.96748, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.1032 - accuracy: 0.9650 - val_loss: 0.0848 - val_accuracy: 0.9675
# Epoch 26/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0939 - accuracy: 0.9688
# Epoch 26: val_accuracy improved from 0.96748 to 0.97019, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.0938 - accuracy: 0.9688 - val_loss: 0.0770 - val_accuracy: 0.9702
# Epoch 27/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0964 - accuracy: 0.9635
# Epoch 27: val_accuracy did not improve from 0.97019
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0962 - accuracy: 0.9636 - val_loss: 0.1979 - val_accuracy: 0.9232
# Epoch 28/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1051 - accuracy: 0.9635
# Epoch 28: val_accuracy did not improve from 0.97019
# 70/70 [==============================] - 8s 117ms/step - loss: 0.1049 - accuracy: 0.9636 - val_loss: 0.1244 - val_accuracy: 0.9566
# Epoch 29/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1055 - accuracy: 0.9579
# Epoch 29: val_accuracy improved from 0.97019 to 0.97200, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.1053 - accuracy: 0.9580 - val_loss: 0.0807 - val_accuracy: 0.9720
# Epoch 30/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0616 - accuracy: 0.9767
# Epoch 30: val_accuracy improved from 0.97200 to 0.97471, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.0615 - accuracy: 0.9767 - val_loss: 0.0613 - val_accuracy: 0.9747
# Epoch 31/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0868 - accuracy: 0.9703
# Epoch 31: val_accuracy did not improve from 0.97471
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0866 - accuracy: 0.9704 - val_loss: 0.1408 - val_accuracy: 0.9503
# Epoch 32/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0951 - accuracy: 0.9649
# Epoch 32: val_accuracy did not improve from 0.97471
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0950 - accuracy: 0.9650 - val_loss: 0.1085 - val_accuracy: 0.9575
# Epoch 33/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0575 - accuracy: 0.9801
# Epoch 33: val_accuracy did not improve from 0.97471
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0574 - accuracy: 0.9801 - val_loss: 0.1256 - val_accuracy: 0.9512
# Epoch 34/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0818 - accuracy: 0.9706
# Epoch 34: val_accuracy did not improve from 0.97471
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0825 - accuracy: 0.9702 - val_loss: 0.1169 - val_accuracy: 0.9566
# Epoch 35/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.1343 - accuracy: 0.9567
# Epoch 35: val_accuracy improved from 0.97471 to 0.98103, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.1340 - accuracy: 0.9568 - val_loss: 0.0592 - val_accuracy: 0.9810
# Epoch 36/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0485 - accuracy: 0.9832
# Epoch 36: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0484 - accuracy: 0.9833 - val_loss: 0.1034 - val_accuracy: 0.9666
# Epoch 37/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9841
# Epoch 37: val_accuracy did not improve from 0.98103
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0437 - accuracy: 0.9842 - val_loss: 0.0703 - val_accuracy: 0.9801
# Epoch 38/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0486 - accuracy: 0.9828
# Epoch 38: val_accuracy improved from 0.98103 to 0.98735, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.0489 - accuracy: 0.9826 - val_loss: 0.0400 - val_accuracy: 0.9874
# Epoch 39/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0564 - accuracy: 0.9785
# Epoch 39: val_accuracy improved from 0.98735 to 0.99097, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.0563 - accuracy: 0.9785 - val_loss: 0.0389 - val_accuracy: 0.9910
# Epoch 40/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0381 - accuracy: 0.9869
# Epoch 40: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0381 - accuracy: 0.9869 - val_loss: 0.0519 - val_accuracy: 0.9783
# Epoch 41/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0329 - accuracy: 0.9875
# Epoch 41: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 116ms/step - loss: 0.0331 - accuracy: 0.9873 - val_loss: 0.1008 - val_accuracy: 0.9630
# Epoch 42/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9871
# Epoch 42: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0394 - accuracy: 0.9871 - val_loss: 0.0383 - val_accuracy: 0.9846
# Epoch 43/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0331 - accuracy: 0.9869
# Epoch 43: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0330 - accuracy: 0.9869 - val_loss: 0.0455 - val_accuracy: 0.9828
# Epoch 44/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0466 - accuracy: 0.9846
# Epoch 44: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0466 - accuracy: 0.9846 - val_loss: 0.0983 - val_accuracy: 0.9657
# Epoch 45/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0456 - accuracy: 0.9839
# Epoch 45: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0455 - accuracy: 0.9840 - val_loss: 0.0633 - val_accuracy: 0.9774
# Epoch 46/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0331 - accuracy: 0.9880
# Epoch 46: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0331 - accuracy: 0.9880 - val_loss: 0.0408 - val_accuracy: 0.9901
# Epoch 47/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0704 - accuracy: 0.9762
# Epoch 47: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0703 - accuracy: 0.9763 - val_loss: 0.0402 - val_accuracy: 0.9874
# Epoch 48/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 0.9907
# Epoch 48: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0262 - accuracy: 0.9907 - val_loss: 0.0367 - val_accuracy: 0.9892
# Epoch 49/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9905
# Epoch 49: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0281 - accuracy: 0.9905 - val_loss: 0.0445 - val_accuracy: 0.9855
# Epoch 50/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0196 - accuracy: 0.9941
# Epoch 50: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0195 - accuracy: 0.9941 - val_loss: 0.0597 - val_accuracy: 0.9783
# Epoch 51/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0787 - accuracy: 0.9715
# Epoch 51: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0785 - accuracy: 0.9715 - val_loss: 0.0481 - val_accuracy: 0.9846
# Epoch 52/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9916
# Epoch 52: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0227 - accuracy: 0.9916 - val_loss: 0.0492 - val_accuracy: 0.9837
# Epoch 53/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9894
# Epoch 53: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0308 - accuracy: 0.9894 - val_loss: 0.0288 - val_accuracy: 0.9901
# Epoch 54/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9860
# Epoch 54: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0339 - accuracy: 0.9860 - val_loss: 0.0589 - val_accuracy: 0.9801
# Epoch 55/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9894
# Epoch 55: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0311 - accuracy: 0.9894 - val_loss: 0.0489 - val_accuracy: 0.9810
# Epoch 56/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0363 - accuracy: 0.9889
# Epoch 56: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0363 - accuracy: 0.9889 - val_loss: 0.0540 - val_accuracy: 0.9792
# Epoch 57/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0441 - accuracy: 0.9839
# Epoch 57: val_accuracy did not improve from 0.99097
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0440 - accuracy: 0.9840 - val_loss: 0.0690 - val_accuracy: 0.9810
# Epoch 58/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0498 - accuracy: 0.9853
# Epoch 58: val_accuracy improved from 0.99097 to 0.99187, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.0498 - accuracy: 0.9853 - val_loss: 0.0262 - val_accuracy: 0.9919
# Epoch 59/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0201 - accuracy: 0.9934
# Epoch 59: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 116ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.1346 - val_accuracy: 0.9566
# Epoch 60/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0619 - accuracy: 0.9823
# Epoch 60: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0618 - accuracy: 0.9824 - val_loss: 0.0426 - val_accuracy: 0.9828
# Epoch 61/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9889
# Epoch 61: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0308 - accuracy: 0.9889 - val_loss: 0.0268 - val_accuracy: 0.9919
# Epoch 62/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0280 - accuracy: 0.9925
# Epoch 62: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0279 - accuracy: 0.9925 - val_loss: 0.0229 - val_accuracy: 0.9901
# Epoch 63/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0303 - accuracy: 0.9896
# Epoch 63: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0302 - accuracy: 0.9896 - val_loss: 0.0521 - val_accuracy: 0.9819
# Epoch 64/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0286 - accuracy: 0.9900
# Epoch 64: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0285 - accuracy: 0.9901 - val_loss: 0.0232 - val_accuracy: 0.9901
# Epoch 65/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0419 - accuracy: 0.9878
# Epoch 65: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0420 - accuracy: 0.9878 - val_loss: 0.3124 - val_accuracy: 0.8907
# Epoch 66/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0418 - accuracy: 0.9860
# Epoch 66: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0418 - accuracy: 0.9860 - val_loss: 0.0339 - val_accuracy: 0.9910
# Epoch 67/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9941
# Epoch 67: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0178 - accuracy: 0.9941 - val_loss: 0.0421 - val_accuracy: 0.9828
# Epoch 68/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0592 - accuracy: 0.9823
# Epoch 68: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0591 - accuracy: 0.9824 - val_loss: 0.0240 - val_accuracy: 0.9901
# Epoch 69/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0266 - accuracy: 0.9914
# Epoch 69: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0281 - accuracy: 0.9912 - val_loss: 0.0251 - val_accuracy: 0.9919
# Epoch 70/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0329 - accuracy: 0.9889
# Epoch 70: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0329 - accuracy: 0.9889 - val_loss: 0.0354 - val_accuracy: 0.9919
# Epoch 71/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9900
# Epoch 71: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0328 - accuracy: 0.9898 - val_loss: 0.0636 - val_accuracy: 0.9738
# Epoch 72/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0416 - accuracy: 0.9873
# Epoch 72: val_accuracy did not improve from 0.99187
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0415 - accuracy: 0.9873 - val_loss: 0.0268 - val_accuracy: 0.9892
# Epoch 73/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9984
# Epoch 73: val_accuracy improved from 0.99187 to 0.99368, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.0214 - val_accuracy: 0.9937
# Epoch 74/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9977
# Epoch 74: val_accuracy did not improve from 0.99368
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.0329 - val_accuracy: 0.9874
# Epoch 75/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9984
# Epoch 75: val_accuracy did not improve from 0.99368
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0174 - val_accuracy: 0.9937
# Epoch 76/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0139 - accuracy: 0.9948
# Epoch 76: val_accuracy did not improve from 0.99368
# 70/70 [==============================] - 8s 116ms/step - loss: 0.0140 - accuracy: 0.9948 - val_loss: 0.2621 - val_accuracy: 0.9467
# Epoch 77/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0337 - accuracy: 0.9903
# Epoch 77: val_accuracy did not improve from 0.99368
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0337 - accuracy: 0.9903 - val_loss: 0.0298 - val_accuracy: 0.9892
# Epoch 78/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9973
# Epoch 78: val_accuracy did not improve from 0.99368
# 70/70 [==============================] - 8s 116ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.0169 - val_accuracy: 0.9928
# Epoch 79/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 0.9943
# Epoch 79: val_accuracy did not improve from 0.99368
# 70/70 [==============================] - 8s 116ms/step - loss: 0.0187 - accuracy: 0.9944 - val_loss: 0.0324 - val_accuracy: 0.9901
# Epoch 80/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9980
# Epoch 80: val_accuracy did not improve from 0.99368
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0091 - accuracy: 0.9977 - val_loss: 0.0247 - val_accuracy: 0.9937
# Epoch 81/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0193 - accuracy: 0.9925
# Epoch 81: val_accuracy did not improve from 0.99368
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0193 - accuracy: 0.9925 - val_loss: 0.0694 - val_accuracy: 0.9801
# Epoch 82/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0202 - accuracy: 0.9934
# Epoch 82: val_accuracy did not improve from 0.99368
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0205 - accuracy: 0.9932 - val_loss: 0.0756 - val_accuracy: 0.9747
# Epoch 83/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0367 - accuracy: 0.9885
# Epoch 83: val_accuracy did not improve from 0.99368
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0367 - accuracy: 0.9885 - val_loss: 0.0175 - val_accuracy: 0.9928
# Epoch 84/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 0.9952
# Epoch 84: val_accuracy improved from 0.99368 to 0.99548, saving model to best_model.h5
# 70/70 [==============================] - 8s 119ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.0122 - val_accuracy: 0.9955
# Epoch 85/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9977
# Epoch 85: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0157 - val_accuracy: 0.9955
# Epoch 86/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9980
# Epoch 86: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0080 - accuracy: 0.9980 - val_loss: 0.0358 - val_accuracy: 0.9874
# Epoch 87/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0211 - accuracy: 0.9930
# Epoch 87: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.0292 - val_accuracy: 0.9892
# Epoch 88/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9955
# Epoch 88: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.1654 - val_accuracy: 0.9566
# Epoch 89/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0462 - accuracy: 0.9873
# Epoch 89: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 116ms/step - loss: 0.0461 - accuracy: 0.9873 - val_loss: 0.0320 - val_accuracy: 0.9864
# Epoch 90/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9989
# Epoch 90: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.0347 - val_accuracy: 0.9892
# Epoch 91/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9982
# Epoch 91: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.0211 - val_accuracy: 0.9928
# Epoch 92/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9984
# Epoch 92: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0076 - accuracy: 0.9984 - val_loss: 0.0354 - val_accuracy: 0.9910
# Epoch 93/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9982
# Epoch 93: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 0.0325 - val_accuracy: 0.9901
# Epoch 94/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0259 - accuracy: 0.9950
# Epoch 94: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0259 - accuracy: 0.9950 - val_loss: 0.0387 - val_accuracy: 0.9837
# Epoch 95/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0562 - accuracy: 0.9808
# Epoch 95: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0561 - accuracy: 0.9808 - val_loss: 0.0225 - val_accuracy: 0.9937
# Epoch 96/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9928
# Epoch 96: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0233 - accuracy: 0.9928 - val_loss: 0.0259 - val_accuracy: 0.9883
# Epoch 97/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9955
# Epoch 97: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.0232 - val_accuracy: 0.9910
# Epoch 98/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9982
# Epoch 98: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0216 - val_accuracy: 0.9919
# Epoch 99/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9986
# Epoch 99: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.0172 - val_accuracy: 0.9937
# Epoch 100/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9995
# Epoch 100: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 8s 117ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.0184 - val_accuracy: 0.9937

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 35/35 [==============================] - 1s 17ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("SquezeNet MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred,average="macro"))
print("Hassasiyet: ",precision_score(Y_val, y_pred,average="macro"))
print("Duyarlılık: ", recall_score(Y_val, y_pred,average="macro"))
# Out:
# SquezeNet MODEL SONUÇLARI
# Doğruluk:  0.995483288166215
# F1_Skor:  0.995549049557645
# Hassasiyet:  0.9955030000575147
# Duyarlılık:  0.9956169716808014

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# [[282   3   0   1]
#  [  1 281   0   0]
#  [  0   0 283   0]
#  [  0   0   0 256]]
# <Axes: >
