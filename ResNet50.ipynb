# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import random
from tqdm import tqdm
import xgboost as xgb
import tensorflow as tf
from keras.applications.resnet50 import ResNet50
# from keras.applications.resnet18 import ResNet18
from keras.models import Model
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Flatten, Input
import scipy
from sklearn.metrics import fbeta_score
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input
from keras.models import Model,Sequential,  load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#from keras.optimizers import adam_v2
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %%
import pandas as pd
import numpy as np
import os
import sys
from shutil import copyfile
import os.path
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array,load_img
from PIL import Image
from sklearn.model_selection import train_test_split
from numpy import load
import matplotlib.pyplot as plt
imagegen = ImageDataGenerator()

# %%
# load train data from drive
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
train_generator=imagegen.flow_from_directory('/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape',
                                             shuffle=False, batch_size=64, target_size=(224, 224),seed=42 )
x=np.concatenate([train_generator.next()[0] for i in range(train_generator.__len__())])
y=np.concatenate([train_generator.next()[1] for i in range(train_generator.__len__())])
print(x.shape)
print(y.shape)
# Out:
# Found 4062 images belonging to 4 classes.
# (4062, 224, 224, 3)
# (4062, 4)

# %%
#Converting  our color images to a vector
x=x.reshape(4062,224*224*3)

# %%
x.shape
# Out:
# (4062, 150528)

# %%
#Apply SMOTE method
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
X_smote, y_smote = sm.fit_resample(x, y)

# %%
X_smote.shape
# Out:
# (5532, 150528)

# %%
X_smote=X_smote.reshape(5532,224,224,3)

# %% [markdown]
# # 1. sınıf: 1179  2. sınıf: 1076 3. sınıf: 1142 4. sınıf: 1180

# %%
print(f'''Shape of X before SMOTE: {x.shape}
Shape of X after SMOTE: {X_smote.shape}''')
# Out:
# Shape of X before SMOTE: (4062, 150528)
# Shape of X after SMOTE: (5532, 224, 224, 3)

# %%
"""
disease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']
data_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
"""
# Out:
# "\ndisease_types=['healthy', 'Leaf_blight', 'Esca', 'Black_rot']\ndata_dir = '/content/drive/MyDrive/BitkiHastaligiTeshisi - OzgeOzaras/Veri setleri/PlantVillage-Grape'\ntrain_dir = os.path.join(data_dir)\n\ntrain_data = []\nfor defects_id, sp in enumerate(disease_types):\n    for file in os.listdir(os.path.join(train_dir, sp)):\n        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])\n\ntrain = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])\n\nSEED = 42\ntrain = train.sample(frac=1, random_state=SEED)\ntrain.index = np.arange(len(train)) # Reset indices\n"

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
"""
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))"""
# Normalize the data
X_smote = X_smote / 255.
print('Train Shape: {}'.format(X_smote.shape))
# Out:
# Train Shape: (5532, 224, 224, 3)

# %%
#Y_train = train['DiseaseID'].values
#Y_train = to_categorical(Y_train)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# %%
EPOCHS = 50
BATCH_SIZE=64
SIZE=224
N_ch=3

# %%
from keras.applications import ResNet50
def build_resnet50():
    resnet = ResNet50(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    x = resnet(x)
    x = Flatten(name="flatten")(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    # multi output
    output = Dense(4,activation = 'softmax', name='root')(x)
    # model
    model = Model(input,output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()

    return model

# %%
model_resnet50 = build_resnet50()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 3)       84
#
#  resnet50 (Functional)       (None, None, None, 2048   23587712
#                              )
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dropout_2 (Dropout)         (None, 100352)            0
#
#  dense_1 (Dense)             (None, 256)               25690368
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 4)                 1028
#
# =================================================================
# Total params: 49280216 (187.99 MB)
# Trainable params: 49226584 (187.78 MB)
# Non-trainable params: 53632 (209.50 KB)
# _________________________________________________________________

# %%
# simple early stopping
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
hist_resnet50 = model_resnet50.fit(X_train, Y_train,
               batch_size=BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               validation_data=(X_val, Y_val),
               callbacks=[es,mc])
# Out:
# Epoch 1/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.9299
# Epoch 1: val_accuracy improved from -inf to 0.23126, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 70/70 [==============================] - 96s 722ms/step - loss: 0.2227 - accuracy: 0.9299 - val_loss: 9.5643 - val_accuracy: 0.2313
# Epoch 2/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9930
# Epoch 2: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 45s 640ms/step - loss: 0.0191 - accuracy: 0.9930 - val_loss: 7.2861 - val_accuracy: 0.2313
# Epoch 3/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9955
# Epoch 3: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 45s 647ms/step - loss: 0.0187 - accuracy: 0.9955 - val_loss: 8.3207 - val_accuracy: 0.2313
# Epoch 4/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9934
# Epoch 4: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 46s 651ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 7.8735 - val_accuracy: 0.2313
# Epoch 5/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9977
# Epoch 5: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 46s 655ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 7.3507 - val_accuracy: 0.2313
# Epoch 6/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9968
# Epoch 6: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 46s 656ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 11.4030 - val_accuracy: 0.2313
# Epoch 7/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 7: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 46s 658ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 7.3122 - val_accuracy: 0.2313
# Epoch 8/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 8: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 6.1040 - val_accuracy: 0.2313
# Epoch 9/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998
# Epoch 9: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 5.1444 - val_accuracy: 0.2313
# Epoch 10/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 10: val_accuracy did not improve from 0.23126
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 4.3389 - val_accuracy: 0.2313
# Epoch 11/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9986
# Epoch 11: val_accuracy improved from 0.23126 to 0.23848, saving model to best_model.h5
# 70/70 [==============================] - 48s 682ms/step - loss: 0.0029 - accuracy: 0.9986 - val_loss: 3.2658 - val_accuracy: 0.2385
# Epoch 12/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9989
# Epoch 12: val_accuracy improved from 0.23848 to 0.25474, saving model to best_model.h5
# 70/70 [==============================] - 48s 682ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 3.2993 - val_accuracy: 0.2547
# Epoch 13/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9941
# Epoch 13: val_accuracy improved from 0.25474 to 0.37398, saving model to best_model.h5
# 70/70 [==============================] - 48s 682ms/step - loss: 0.0228 - accuracy: 0.9941 - val_loss: 2.5133 - val_accuracy: 0.3740
# Epoch 14/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9989
# Epoch 14: val_accuracy improved from 0.37398 to 0.63144, saving model to best_model.h5
# 70/70 [==============================] - 48s 681ms/step - loss: 0.0049 - accuracy: 0.9989 - val_loss: 1.2383 - val_accuracy: 0.6314
# Epoch 15/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9993
# Epoch 15: val_accuracy improved from 0.63144 to 0.77597, saving model to best_model.h5
# 70/70 [==============================] - 48s 683ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.7415 - val_accuracy: 0.7760
# Epoch 16/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9986
# Epoch 16: val_accuracy improved from 0.77597 to 0.87715, saving model to best_model.h5
# 70/70 [==============================] - 48s 684ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.4720 - val_accuracy: 0.8771
# Epoch 17/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9993
# Epoch 17: val_accuracy improved from 0.87715 to 0.94219, saving model to best_model.h5
# 70/70 [==============================] - 48s 683ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.2264 - val_accuracy: 0.9422
# Epoch 18/50
# 70/70 [==============================] - ETA: 0s - loss: 9.6608e-04 - accuracy: 0.9998
# Epoch 18: val_accuracy improved from 0.94219 to 0.97742, saving model to best_model.h5
# 70/70 [==============================] - 48s 682ms/step - loss: 9.6608e-04 - accuracy: 0.9998 - val_loss: 0.0796 - val_accuracy: 0.9774
# Epoch 19/50
# 70/70 [==============================] - ETA: 0s - loss: 8.7985e-04 - accuracy: 1.0000
# Epoch 19: val_accuracy improved from 0.97742 to 0.99006, saving model to best_model.h5
# 70/70 [==============================] - 48s 682ms/step - loss: 8.7985e-04 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 0.9901
# Epoch 20/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9980
# Epoch 20: val_accuracy improved from 0.99006 to 0.99187, saving model to best_model.h5
# 70/70 [==============================] - 48s 681ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0272 - val_accuracy: 0.9919
# Epoch 21/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9989
# Epoch 21: val_accuracy improved from 0.99187 to 0.99368, saving model to best_model.h5
# 70/70 [==============================] - 48s 682ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0267 - val_accuracy: 0.9937
# Epoch 22/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9995
# Epoch 22: val_accuracy improved from 0.99368 to 0.99548, saving model to best_model.h5
# 70/70 [==============================] - 48s 684ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0176 - val_accuracy: 0.9955
# Epoch 23/50
# 70/70 [==============================] - ETA: 0s - loss: 4.8351e-04 - accuracy: 0.9998
# Epoch 23: val_accuracy did not improve from 0.99548
# 70/70 [==============================] - 46s 659ms/step - loss: 4.8351e-04 - accuracy: 0.9998 - val_loss: 0.0225 - val_accuracy: 0.9937
# Epoch 24/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 24: val_accuracy improved from 0.99548 to 0.99639, saving model to best_model.h5
# 70/70 [==============================] - 48s 682ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9964
# Epoch 25/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9995
# Epoch 25: val_accuracy did not improve from 0.99639
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0271 - val_accuracy: 0.9937
# Epoch 26/50
# 70/70 [==============================] - ETA: 0s - loss: 5.1301e-04 - accuracy: 0.9998
# Epoch 26: val_accuracy improved from 0.99639 to 0.99819, saving model to best_model.h5
# 70/70 [==============================] - 48s 681ms/step - loss: 5.1301e-04 - accuracy: 0.9998 - val_loss: 0.0111 - val_accuracy: 0.9982
# Epoch 27/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 27: val_accuracy improved from 0.99819 to 0.99910, saving model to best_model.h5
# 70/70 [==============================] - 48s 684ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0079 - val_accuracy: 0.9991
# Epoch 28/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9959
# Epoch 28: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 658ms/step - loss: 0.0182 - accuracy: 0.9959 - val_loss: 0.0419 - val_accuracy: 0.9892
# Epoch 29/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998
# Epoch 29: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0185 - val_accuracy: 0.9955
# Epoch 30/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9993
# Epoch 30: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0165 - val_accuracy: 0.9946
# Epoch 31/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9939
# Epoch 31: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0243 - accuracy: 0.9939 - val_loss: 0.0520 - val_accuracy: 0.9892
# Epoch 32/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9975
# Epoch 32: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0166 - val_accuracy: 0.9946
# Epoch 33/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9998
# Epoch 33: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.0184 - val_accuracy: 0.9955
# Epoch 34/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9995
# Epoch 34: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 660ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0205 - val_accuracy: 0.9937
# Epoch 35/50
# 70/70 [==============================] - ETA: 0s - loss: 3.9047e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 3.9047e-04 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 0.9955
# Epoch 36/50
# 70/70 [==============================] - ETA: 0s - loss: 4.1602e-04 - accuracy: 0.9998
# Epoch 36: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 660ms/step - loss: 4.1602e-04 - accuracy: 0.9998 - val_loss: 0.0152 - val_accuracy: 0.9955
# Epoch 37/50
# 70/70 [==============================] - ETA: 0s - loss: 2.3296e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 2.3296e-04 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 0.9955
# Epoch 38/50
# 70/70 [==============================] - ETA: 0s - loss: 2.5019e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 2.5019e-04 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 0.9955
# Epoch 39/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9986
# Epoch 39: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.0166 - val_accuracy: 0.9964
# Epoch 40/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 40: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0053 - val_accuracy: 0.9982
# Epoch 41/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9966
# Epoch 41: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0612 - val_accuracy: 0.9828
# Epoch 42/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9946
# Epoch 43/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9977
# Epoch 43: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 658ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0138 - val_accuracy: 0.9955
# Epoch 44/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9937
# Epoch 44: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 658ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0176 - val_accuracy: 0.9928
# Epoch 45/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9991
# Epoch 45: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0035 - val_accuracy: 0.9991
# Epoch 46/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9966
# Epoch 46: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0139 - accuracy: 0.9966 - val_loss: 0.0118 - val_accuracy: 0.9973
# Epoch 47/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 47: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9982
# Epoch 48/50
# 70/70 [==============================] - ETA: 0s - loss: 4.5804e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 4.5804e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9982
# Epoch 49/50
# 70/70 [==============================] - ETA: 0s - loss: 3.9520e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 3.9520e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 0.9991
# Epoch 50/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 50: val_accuracy did not improve from 0.99910
# 70/70 [==============================] - 46s 659ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0020 - val_accuracy: 0.9991

# %%
# load the saved model
saved_model = load_model('best_model.h5')

# %%
y_pred = saved_model.predict(X_val)
# Out:
# 35/35 [==============================] - 5s 86ms/step

# %%
y_pred=np.argmax(y_pred, axis=1)

# %%
Y_val=np.argmax(Y_val, axis=1)

# %%
print("RESNET50 MODEL SONUÇLARI")
print("Doğruluk: ",accuracy_score(Y_val, y_pred))
print("F1_Skor: ", f1_score(Y_val, y_pred, average='macro'))
print("Hassasiyet: ",precision_score(Y_val, y_pred, average='macro'))
print("Duyarlılık: ", recall_score(Y_val, y_pred, average='macro'))
# Out:
# RESNET50 MODEL SONUÇLARI
# Doğruluk:  0.999096657633243
# F1_Skor:  0.9991196937526153
# Hassasiyet:  0.9991166077738516
# Duyarlılık:  0.9991258741258742

# %%
plt.plot(hist_resnet50.history['accuracy'])
plt.plot(hist_resnet50.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# VGG16 loss plot
plt.plot(hist_resnet50.history['loss'])
plt.plot(hist_resnet50.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import seaborn as sn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(Y_val, y_pred)
print(cm)
sn.set(font_scale=1.2)#for label size
sn.heatmap(cm, annot=True,fmt="d", linewidths=.5 ,annot_kws={"size": 16})# font size
# Out:
# [[285   1   0   0]
#  [  0 282   0   0]
#  [  0   0 283   0]
#  [  0   0   0 256]]
# <Axes: >
